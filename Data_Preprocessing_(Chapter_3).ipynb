# %% [markdown]
# <a href="https://colab.research.google.com/github/tohnperfect/DPDM2021/blob/main/Data_Preprocessing_(Chapter_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # ทำงานกับข้อมูลลักษณะ ตาราง

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DPDM2021_DATA'
data_cases = pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.loc[data_cases['announce_date']=='26/7/2021'].index
# Out:
# Int64Index([497246, 497247, 497248, 497249, 497250, 497251, 497252, 497253,
#             497254, 497255,
#             ...
#             512612, 512613, 512614, 512615, 512616, 512617, 512618, 512619,
#             512620, 512621],
#            dtype='int64', length=15376)

# %% [markdown]
# # ชี้ข้อมูลในตาราง

# %%
data_cases['risk']
# Out:
# 0         คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         คนต่างชาติเดินทางมาจากต่างประเทศ
#                         ...
# 512617                    ทัณฑสถาน/เรือนจำ
# 512618                    ทัณฑสถาน/เรือนจำ
# 512619                    ทัณฑสถาน/เรือนจำ
# 512620                    ทัณฑสถาน/เรือนจำ
# 512621                    ทัณฑสถาน/เรือนจำ
# Name: risk, Length: 512622, dtype: object

# %%
data_cases[['risk','age']]
# Out:
#                                     risk   age
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ  61.0
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ  74.0
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ  73.0
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ  68.0
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ  66.0
# ...                                  ...   ...
# 512617                  ทัณฑสถาน/เรือนจำ   NaN
# 512618                  ทัณฑสถาน/เรือนจำ   NaN
# 512619                  ทัณฑสถาน/เรือนจำ   NaN
# 512620                  ทัณฑสถาน/เรือนจำ   NaN
# 512621                  ทัณฑสถาน/เรือนจำ   NaN
#
# [512622 rows x 2 columns]

# %%
data_cases['risk'][666]
# Out:
# 'สนามมวย'

# %% [markdown]
# # ชี้โดยใช้ .iloc[] (แปลงมุมมองให้เป็น matrix)

# %%
data_cases.iloc[4,4]
# Out:
# 66.0

# %%
data_cases.iloc[-50:,:]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 512572  512573     26/7/2021  ...               NaN               NaN
# 512573  512574     26/7/2021  ...               NaN               NaN
# 512574  512575     26/7/2021  ...               NaN               NaN
# 512575  512576     26/7/2021  ...               NaN               NaN
# 512576  512577     26/7/2021  ...               NaN               NaN
# 512577  512578     26/7/2021  ...               NaN               NaN
# 512578  512579     26/7/2021  ...               NaN               NaN
# 512579  512580     26/7/2021  ...               NaN               NaN
# 512580  512581     26/7/2021  ...               NaN               NaN
# 512581  512582     26/7/2021  ...               NaN               NaN
# 512582  512583     26/7/2021  ...               NaN               NaN
# 512583  512584     26/7/2021  ...               NaN               NaN
# 512584  512585     26/7/2021  ...               NaN               NaN
# 512585  512586     26/7/2021  ...               NaN               NaN
# 512586  512587     26/7/2021  ...               NaN               NaN
# 512587  512588     26/7/2021  ...               NaN               NaN
# 512588  512589     26/7/2021  ...               NaN               NaN
# 512589  512590     26/7/2021  ...               NaN               NaN
# 512590  512591     26/7/2021  ...               NaN               NaN
# 512591  512592     26/7/2021  ...               NaN               NaN
# 512592  512593     26/7/2021  ...               NaN               NaN
# 512593  512594     26/7/2021  ...               NaN               NaN
# 512594  512595     26/7/2021  ...               NaN               NaN
# 512595  512596     26/7/2021  ...               NaN               NaN
# 512596  512597     26/7/2021  ...               NaN               NaN
# 512597  512598     26/7/2021  ...               NaN               NaN
# 512598  512599     26/7/2021  ...               NaN               NaN
# 512599  512600     26/7/2021  ...               NaN               NaN
# 512600  512601     26/7/2021  ...               NaN               NaN
# 512601  512602     26/7/2021  ...               NaN               NaN
# 512602  512603     26/7/2021  ...               NaN               NaN
# 512603  512604     26/7/2021  ...               NaN               NaN
# 512604  512605     26/7/2021  ...               NaN               NaN
# 512605  512606     26/7/2021  ...               NaN               NaN
# 512606  512607     26/7/2021  ...               NaN               NaN
# 512607  512608     26/7/2021  ...               NaN               NaN
# 512608  512609     26/7/2021  ...               NaN               NaN
# 512609  512610     26/7/2021  ...               NaN               NaN
# 512610  512611     26/7/2021  ...               NaN               NaN
# 512611  512612     26/7/2021  ...               NaN               NaN
# 512612  512613     26/7/2021  ...               NaN               NaN
# 512613  512614     26/7/2021  ...               NaN               NaN
# 512614  512615     26/7/2021  ...               NaN               NaN
# 512615  512616     26/7/2021  ...               NaN               NaN
# 512616  512617     26/7/2021  ...               NaN               NaN
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [50 rows x 11 columns]

# %%
data_cases.iloc[-50:,[3,6,8]]
# Out:
#          sex nationality              risk
# 512572  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512573  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512574  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512575  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512576  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512577  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512578  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512579  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512580  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512581  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512582  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512583  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512584  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512585  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512586  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512587  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512588  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512589  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512590  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512591  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512592  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512593  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512594  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512595  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512596  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512597  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512598   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512599  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512600  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512601  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512602  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512603  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512604  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512605  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512606  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512607  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512608  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512609  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512610  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512611  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512612  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512613   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512614   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512615   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512616   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512617   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512618   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512619   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512620   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512621   ชาย         NaN  ทัณฑสถาน/เรือนจำ

# %% [markdown]
# # Descriptive Statistics of Data

# %%
data_cases.describe()
# Out:
#                  No.            age
# count  512622.000000  462839.000000
# mean   256311.500000      35.529470
# std    147981.369183      16.153885
# min         1.000000       1.000000
# 25%    128156.250000      25.000000
# 50%    256311.500000      34.000000
# 75%    384466.750000      46.000000
# max    512622.000000     108.000000

# %% [markdown]
# # Missing Value
#
#
#
# *   Null
# *   NaN = Not a Number
# *   NA = Not available

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull()
# Out:
#           No.  announce_date  ...  province_of_onset  district_of_onset
# 0       False          False  ...              False               True
# 1       False          False  ...              False               True
# 2       False          False  ...              False              False
# 3       False          False  ...              False               True
# 4       False          False  ...              False               True
# ...       ...            ...  ...                ...                ...
# 512617  False          False  ...               True               True
# 512618  False          False  ...               True               True
# 512619  False          False  ...               True               True
# 512620  False          False  ...               True               True
# 512621  False          False  ...               True               True
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull().any()  # .any() คือ Or ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases.isnull().any().any()
# Out:
# True

# %%
data_cases.isnull().all()  # .all() คือ and ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# # Handling Missing Value 1 (ลบค่า missing )

# %%
data_cases.shape
# Out:
# (512622, 11)

# %%
data_cases_M1 = data_cases.dropna()

# %%
data_cases_M1.shape
# Out:
# (362205, 11)

# %% [markdown]
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data

# %%
print('size before drop = ',len(data_cases))
print('size after drop = ', len(data_cases_M1))
print('we lost ', ((len(data_cases)-len(data_cases_M1))/len(data_cases))*100, '% of data')
# Out:
# size before drop =  512622
# size after drop =  362205
# we lost  29.342673548930794 % of data

# %%
print(f'size before drop = {len(data_cases)}')
print('size after drop = ', len(data_cases_M1))
print(f'we lost {((len(data_cases)-len(data_cases_M1))/len(data_cases))*100:.2f}% of data')
# Out:
# size before drop = 512622
# size after drop =  362205
# we lost 29.34% of data

# %% [markdown]
# ## Handling Missing Value 1.5 (ลบค่า missing เฉพาะใน column ที่เราสนใจ)

# %%
data_cases_M15 = data_cases.dropna(subset=['Notified date', 'sex', 'age'])

# %%
data_cases_M15.shape
# Out:
# (449552, 11)

# %% [markdown]
# HW
#
# ```print``` ของ missing 1.5
#
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data
#
# now we have x% more data than handling_missing1

# %% [markdown]
# ## Handling Missing Value 2 แทนด้วยค่าที่เหมาะสมหรือสร้าง class ใหม่

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases['age'].mean(skipna=False) ## ถ้า function ไม่ได้ป้องกัน data ที่มี missing ไว้
# Out:
# nan

# %%
data_cases[['Notified date']] = data_cases[['Notified date']].fillna('99/99/9999')

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ### ดู column unit

# %%
data_cases['Unit']
# Out:
# 0          ปี
# 1          ปี
# 2          ปี
# 3          ปี
# 4          ปี
#          ...
# 512617    NaN
# 512618    NaN
# 512619    NaN
# 512620    NaN
# 512621    NaN
# Name: Unit, Length: 512622, dtype: object

# %%
set(data_cases['Unit']) ## หา unique values
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %% [markdown]
# ## [PD] วิธีเลือก record โดยการกำหนดค่า

# %%
data_cases[data_cases['Unit']=='วัน']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 19706    19707      2/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 23791    23792     10/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 40962    40963     18/4/2021  ...        นครราชสีมา           เสิงสาง
# 57747    57748     27/4/2021  ...               NaN               NaN
# 72457    72458      4/5/2021  ...     กรุงเทพมหานคร            สายไหม
# ...        ...           ...  ...               ...               ...
# 443474  443475     22/7/2021  ...            นครปฐม           สามพราน
# 474582  474583     24/7/2021  ...        ฉะเชิงเทรา           บางปะกง
# 477365  477366     24/7/2021  ...      สุราษฎร์ธานี            พุนพิน
# 488901  488902     25/7/2021  ...            ชลบุรี          บางละมุง
# 504780  504781     26/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
#
# [64 rows x 11 columns]

# %%
data_cases[data_cases['Unit']==' วัน']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 138721  138722     27/5/2021  ...       สมุทรปราการ            บางพลี
#
# [1 rows x 11 columns]

# %% [markdown]
# ```python
# data_frame[list_of_logics] #list_of_logics มีขนาดเท่ากับจำนวน record ของ data_frame
# ```

# %%
data_cases['Unit']=='วัน'  # list_of_logics
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 512617    False
# 512618    False
# 512619    False
# 512620    False
# 512621    False
# Name: Unit, Length: 512622, dtype: bool

# %%
data_cases[data_cases['Unit']=='วัน'].sort_values(by='age')
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 339653  339654     12/7/2021  ...       สมุทรปราการ            บางพลี
# 375821  375822     16/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
# 367305  367306     15/7/2021  ...       สมุทรปราการ  เมืองสมุทรปราการ
# 377872  377873     16/7/2021  ...     กรุงเทพมหานคร               NaN
# 409055  409056     19/7/2021  ...       สมุทรปราการ         พระประแดง
# ...        ...           ...  ...               ...               ...
# 19706    19707      2/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 321015  321016     10/7/2021  ...       สมุทรปราการ  เมืองสมุทรปราการ
# 291137  291138      6/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
# 443474  443475     22/7/2021  ...            นครปฐม           สามพราน
# 285988  285989      5/7/2021  ...            ชลบุรี           ศรีราชา
#
# [64 rows x 11 columns]

# %% [markdown]
# Quiz 10
# หา records ต่อไปนี้
#
# ~records ที่ กักตัวที่ขอนแก่น~ Oil
#
# ~records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร~ Kie
#
# ~records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม~ Kie
#
# ~records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่~ Nicha

# %% [markdown]
# records ที่ กักตัวที่ขอนแก่น

# %%
data_cases[data_cases['province_of_isolation']=='ขอนแก่น']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 505598  505599     26/7/2021  ...           ขอนแก่น           ภูเวียง
# 505599  505600     26/7/2021  ...           ขอนแก่น           ภูเวียง
# 511809  511810     26/7/2021  ...               NaN               NaN
# 511810  511811     26/7/2021  ...               NaN               NaN
# 511811  511812     26/7/2021  ...               NaN               NaN
#
# [3707 rows x 11 columns]

# %% [markdown]
# records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร

# %%
data_cases[(data_cases['province_of_isolation']=='ขอนแก่น') | (data_cases['province_of_isolation']=='นครราชสีมา') |
           (data_cases['province_of_isolation']=='อุดรธานี')]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 189        190     18/3/2020  ...        นครราชสีมา             พิมาย
# 207        208     18/3/2020  ...     กรุงเทพมหานคร               NaN
# 212        213     18/3/2020  ...        นครราชสีมา       วังน้ำเขียว
# 284        285     20/3/2020  ...        นครราชสีมา   เมืองนครราชสีมา
# ...        ...           ...  ...               ...               ...
# 507218  507219     26/7/2021  ...               NaN               NaN
# 507219  507220     26/7/2021  ...               NaN               NaN
# 511809  511810     26/7/2021  ...               NaN               NaN
# 511810  511811     26/7/2021  ...               NaN               NaN
# 511811  511812     26/7/2021  ...               NaN               NaN
#
# [10539 rows x 11 columns]

# %% [markdown]
# records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม

# %%
data_cases[(data_cases['province_of_onset']=='กรุงเทพมหานคร') & (data_cases['sex']=='หญิง')]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5            6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6            7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 511560  511561     26/7/2021  ...     กรุงเทพมหานคร            ธนบุรี
# 511562  511563     26/7/2021  ...     กรุงเทพมหานคร         คลองสามวา
# 511566  511567     26/7/2021  ...     กรุงเทพมหานคร       บางขุนเทียน
# 511574  511575     26/7/2021  ...     กรุงเทพมหานคร         ลาดกระบัง
# 511577  511578     26/7/2021  ...     กรุงเทพมหานคร            บางบอน
#
# [58896 rows x 11 columns]

# %% [markdown]
# records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่

# %%
data_cases[(data_cases['province_of_isolation']=='เชียงใหม่') & 
           (data_cases['sex']=='ชาย') &
           (data_cases['age']>=18) &
           (data_cases['age']<=22)].sort_values(by='age')
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 37385    37386     15/4/2021  ...         เชียงใหม่            แม่ออน
# 38887    38888     16/4/2021  ...         เชียงใหม่         ดอยสะเก็ด
# 81287    81288      9/5/2021  ...         เชียงใหม่           สันทราย
# 47078    47079     22/4/2021  ...         เชียงใหม่            แม่ริม
# 78869    78870      8/5/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# ...        ...           ...  ...               ...               ...
# 34470    34471     13/4/2021  ...         เชียงใหม่               NaN
# 34445    34446     13/4/2021  ...         เชียงใหม่               NaN
# 34439    34440     13/4/2021  ...         เชียงใหม่               NaN
# 34506    34507     13/4/2021  ...         เชียงใหม่               NaN
# 497302  497303     26/7/2021  ...         เชียงใหม่             หางดง
#
# [411 rows x 11 columns]

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data_cases['Unit'].dropna())
# Out:
# (array([4.61483e+05, 0.00000e+00, 1.43600e+03, 0.00000e+00, 0.00000e+00,
#         6.40000e+01, 0.00000e+00, 3.90000e+01, 0.00000e+00, 1.00000e+00]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
data_cases[['Unit']] = data_cases[['Unit']].fillna('ปี')

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['nationality']] = data_cases[['nationality']].fillna('ไทย?')

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# ## Handling Missing Value 3 แทนด้วยค่าด้วยค่ากลาง

# %%
data_cases[['age']] = data_cases[['age']].fillna(data_cases['age'].mean())

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['sex']].dropna().mode()
# Out:
#    sex
# 0  ชาย

# %%
data_cases[['sex']].dropna().mode().iloc[0,0]
# Out:
# 'ชาย'

# %%
data_cases[['sex']] = data_cases[['sex']].fillna(data_cases[['sex']].dropna().mode().iloc[0,0])
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ## Loop [PD]

# %%
for i in range(10):
    print(data_cases.iloc[i,:])
    print('------------------new line---------------')
# Out:
# No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    61
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 0
# Name: 0, dtype: object
# ------------------new line---------------
# No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    74
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 1
# Name: 1, dtype: object
# ------------------new line---------------
# No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# new col                                                 2
# Name: 2, dtype: object
# ------------------new line---------------
# No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    68
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 3
# Name: 3, dtype: object
# ------------------new line---------------
# No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    66
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 4
# Name: 4, dtype: object
# ------------------new line---------------
# No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    33
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 5
# Name: 5, dtype: object
# ------------------new line---------------
# No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    57
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 6
# Name: 6, dtype: object
# ------------------new line---------------
# No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# new col                                                 7
# Name: 7, dtype: object
# ------------------new line---------------
# No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    63
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 8
# Name: 8, dtype: object
# ------------------new line---------------
# No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    28
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# new col                                                 9
# Name: 9, dtype: object
# ------------------new line---------------

# %%
for record in data_cases.iloc[:10,:].iterrows():
    print(record)
    print('------------------new line---------------')
# Out:
# (0, No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    61
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 0
# Name: 0, dtype: object)
# ------------------new line---------------
# (1, No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    74
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 1
# Name: 1, dtype: object)
# ------------------new line---------------
# (2, No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# new col                                                 2
# Name: 2, dtype: object)
# ------------------new line---------------
# (3, No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    68
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 3
# Name: 3, dtype: object)
# ------------------new line---------------
# (4, No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    66
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 4
# Name: 4, dtype: object)
# ------------------new line---------------
# (5, No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    33
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 5
# Name: 5, dtype: object)
# ------------------new line---------------
# (6, No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    57
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 6
# Name: 6, dtype: object)
# ------------------new line---------------
# (7, No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# new col                                                 7
# Name: 7, dtype: object)
# ------------------new line---------------
# (8, No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    63
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# new col                                                 8
# Name: 8, dtype: object)
# ------------------new line---------------
# (9, No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    28
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# new col                                                 9
# Name: 9, dtype: object)
# ------------------new line---------------

# %% [markdown]
# ## เราสามารถกำหนดค่าให้กับตารางทีละ column หรือสร้าง
# ## column ใหม่ให้กับตาราง ได้โดยใช้ list ที่มีจำนวนเท่ากับจำนวน record

# %%
data_cases['new col'] = list(range(data_cases.shape[0]))

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %% [markdown]
# # แก้ missing ใน province_of_isolation เติมค่าของ onset ใน isolation ก่อนจะเติมค่า mode

# %%
new_p_iso = list()

for row in data_cases.iterrows():
    if pd.isna(row[1]['province_of_isolation']):
        if pd.isna(row[1]['province_of_onset']) == False:
            new_p_iso.append(row[1]['province_of_onset'])
        else:
            new_p_iso.append(data_cases[['province_of_isolation']].dropna().mode().iloc[0,0])
    else:
        new_p_iso.append(row[1]['province_of_isolation'])

# %%
len(new_p_iso)
# Out:
# 512622

# %%
data_cases['province_of_isolation'] = new_p_iso

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
data_cases2 = pd.read_csv(os.path.join(path,'confirmed-cases.csv'))

# %%
data_cases2[pd.isna(data_cases2['province_of_isolation'])]
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 39        40     26/2/2020  ...     กรุงเทพมหานคร          ดอนเมือง
# 40        41     28/2/2020  ...           นนทบุรี               NaN
# 41        42     29/2/2020  ...     กรุงเทพมหานคร        วังทองหลาง
# 42        43      2/3/2020  ...     กรุงเทพมหานคร              สาทร
# 140      141     16/3/2020  ...     กรุงเทพมหานคร               NaN
# ...      ...           ...  ...               ...               ...
# 40815  40816     18/4/2021  ...               NaN               NaN
# 40816  40817     18/4/2021  ...               NaN               NaN
# 40817  40818     18/4/2021  ...               NaN               NaN
# 40830  40831     18/4/2021  ...               NaN               NaN
# 40831  40832     18/4/2021  ...               NaN               NaN
#
# [508 rows x 11 columns]

# %%
data_cases[pd.isna(data_cases2['province_of_isolation'])]
# Out:
#          No. announce_date  ... district_of_onset new col
# 39        40     26/2/2020  ...          ดอนเมือง      39
# 40        41     28/2/2020  ...               NaN      40
# 41        42     29/2/2020  ...        วังทองหลาง      41
# 42        43      2/3/2020  ...              สาทร      42
# 140      141     16/3/2020  ...               NaN     140
# ...      ...           ...  ...               ...     ...
# 40815  40816     18/4/2021  ...               NaN   40815
# 40816  40817     18/4/2021  ...               NaN   40816
# 40817  40818     18/4/2021  ...               NaN   40817
# 40830  40831     18/4/2021  ...               NaN   40830
# 40831  40832     18/4/2021  ...               NaN   40831
#
# [508 rows x 12 columns]

# %% [markdown]
# ## Handling Missing Value 4 แทนด้วยค่าด้วยค่ากลางของกลุ่ม

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
risk_list = list(set(data_cases['risk']))
print(risk_list)
# Out:
# [nan, 'รับจ้างขนของที่ตลาดท่ายาง', 'Cluster คลองเตย', 'ไปยังพื้นที่ที่มีการระบาด', 'Cluster ปากช่อง', 'คนไทยมาจากพื้นที่เสี่ยง', 'อื่น', 'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน', 'Cluster ตราด ', 'Cluster โรงงาน standard can', 'Cluster โรงงาน  Big Star', 'คนไทยเดินทางมาจากต่างประเทศ', 'Cluster ตลาดสี่มุมเมือง', 'Cluster ชลบุรี บริษัทไดกิ้น', 'สนามมวย', 'Cluster บางแค', 'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า', 'อยู่ระหว่างการสอบสวน\n', 'คนต่างชาติเดินทางมาจากต่างประเทศ', 'สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)', 'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)', 'ผับหัวหิน', 'Cluster จันทบุรี (ชาวกินี)', 'อาศัย/เดินทางไปในพื้นที่ที่มีการระบาด', 'Cluster งานมอเตอร์ โชว์', 'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน', 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้', 'Cluster ตลาดพรพัฒน์', 'Cluster ตลาดบางพลี', "Cluster Memory 90's กรุงเทพมหานคร", 'รอประสาน', 'Cluster ผับ Thonglor', 'Cluster ระยอง วิริยะประกันภัย', 'สัมผัสผู้ป่วยยืนยัน', 'Cluster ตราด', 'ACF เคหะหลักสี่', 'สัมผัสผู้เดินทางจากต่างประเทศ', 'Cluster ชลบุรี โรงเบียร์ 90', 'ระบุไม่ได้', 'Cluster โรงงาน QPP ประจวบฯ', 'Cluster New Jazz กรุงเทพมหานคร', 'ระหว่างสอบสวน', 'Cluster เรือนจำพิเศษกรุงเทพ', 'อยุ่ระหว่างสอบสวน', 'Cluster Icon siam', 'Cluster ตลาดบางแค', 'Cluster ตลาดบางแค/คลองขวาง', 'Cluster สถานบันเทิงย่านทองหล่อ', 'สัมผัสในสถานพยาบาล', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ', 'อื่นๆ', 'Cluster เรือนจำพิเศษมีนบุรี', 'ACF รองเมือง', 'เดินทางมาจากพื้นที่จังหวัดเสี่ยง', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ', 'ตรวจก่อนทำหัตถการ', 'สถานบันเทิง', 'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว', 'Cluster กรุงเทพมหานคร. คลองเตย', 'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานครมหานคร', 'Cluster บ่อนพัทยา/ชลบุรี', 'เดินทางมาจากพื้นที่เสี่ยงที่มีการระบาดของโรค', 'Cluster เรือนจำกลางคลองเปรม', 'สถานที่ทำงาน', 'Cluster ห้างแสงทอง (สายล่าง)', 'อยู่ระหว่างสอบสวน', 'Cluster ระยอง', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ', 'Refer in', 'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต', 'Cluster ทัณฑสถานหญิงกลาง', 'ผู้ป่วย กรุงเทพมหานคร', 'สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน', 'คนไทยเดินทางกลับจากต่างประเทศ', 'ไปแหล่งชุมชน/สถานที่คนหนาแน่น', 'สัมผัสผู้ป่วยที่ติดโควิด', 'ทัณฑสถาน/เรือนจำ', 'Cluster The Lounge Salaya', 'Cluster จนท. สนามบินสุวรรณภูมิ', 'Cluster สมุทรปราการ ตลาดเคหะบางพลี', 'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)', '2.สัมผัสผู้ติดเชื้อ', 'SHUI', 'Cluster ตลาดนนทบุรี', 'ตลาด', 'Cluster สมุทรปราการ GRP Hightech', 'อยู่ระหว่างการสอบสวน', 'Cluster มหาสารคาม', 'สัมผัสผู้ป่วยยืนยัน \n อยู่ระหว่างสอบสวน', 'ปอดอักเสบ (Pneumonia)', 'Cluster ทัณฑสถานโรงพยาบาลราชทัณฑ์', 'สัมผัสผู้ติดเชื้อยืนยัน อยู่ระหว่างสอบสวน', 'ACF สีลม', 'ปอดอักเสบ Pneumonia', 'เดินทางมาจากพื้นที่มีการระบาดของโรค', 'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน', 'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)', 'ผู้ป่วย PUI', 'ACF สนามกีฬาธูปะเตมีย์', 'Sandbox', 'ศูนย์กักกัน ผู้ต้องกัก', 'Cluster บริษัทศรีสวัสดิ์', 'ผู้ติดเชื้อในประเทศ', 'อยู่ระหว่างสอบสวนโรค', 'State Quarantine', 'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน', 'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar', 'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร.', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ', 'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน', 'Cluster เรือนจำพิเศษธนบุรี', 'Cluster โรงงาน Big Star', 'Cluster จันทบุรี', 'บุคลากรด้านการแพทย์และสาธารณสุข', 'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น', 'Cluster บ่อนไก่อ่างทอง', 'ร้านอาหาร', 'Cluster ทันฑสถานบำบัดพิเศษกลาง', 'ACF สนามกีฬาไทย-ญี่ปุ่น', 'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน', 'Cluster ชลบุรี', 'ระหว่างการสอบสวนโรค', 'Cluster โรงงานทำขนม บางขุนเทียน', 'Cluster บ่อนเทพารักษ์', 'ค้นหาเชิงรุก', 'ตรวจสุขภาพแรงงานต่างด้าว', 'สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน', 'Cluster สมุทรสาคร', 'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)', 'Cluster จันทบุรี (ชาวกินี )', 'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า', 'พิธีกรรมทางศาสนา']

# %% [markdown]
# ทำของขอนแก่น

# %%
dataKK = data_cases[data_cases['province_of_onset']=='ขอนแก่น']

# %%
dataKK[['risk']] = dataKK[['risk']].fillna(dataKK[['risk']].dropna().mode().iloc[0,0])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dataKK
# Out:
#            No. announce_date  ... district_of_onset new col
# 181        182     18/3/2020  ...             เมือง     181
# 463        464     22/3/2020  ...             เมือง     463
# 1467      1468     30/3/2020  ...             เมือง    1467
# 1971      1972      3/4/2020  ...             เมือง    1971
# 2638      2639     15/4/2020  ...            น้ำพอง    2638
# ...        ...           ...  ...               ...     ...
# 507541  507542     26/7/2021  ...               NaN  507541
# 507542  507543     26/7/2021  ...               NaN  507542
# 507543  507544     26/7/2021  ...               NaN  507543
# 507544  507545     26/7/2021  ...               NaN  507544
# 507546  507547     26/7/2021  ...               NaN  507546
#
# [3149 rows x 12 columns]

# %%
dataKK[['risk']].dropna().mode().iloc[0,0]
# Out:
# 'ทัณฑสถาน/เรือนจำ'

# %%
dataKK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
dataCN = data_cases[data_cases['province_of_onset']=='ชลบุรี']

# %%
dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dataCN
# Out:
#            No. announce_date  ... district_of_onset new col
# 31          32      8/2/2020  ...               NaN      31
# 43          44      5/3/2020  ...           ศรีราชา      43
# 44          45      5/3/2020  ...               NaN      44
# 154        155     17/3/2020  ...             เมือง     154
# 222        223     19/3/2020  ...               NaN     222
# ...        ...           ...  ...               ...     ...
# 507502  507503     26/7/2021  ...               NaN  507502
# 507627  507628     26/7/2021  ...           บ้านบึง  507627
# 507628  507629     26/7/2021  ...           บ้านบึง  507628
# 507629  507630     26/7/2021  ...           บ้านบึง  507629
# 508638  508639     26/7/2021  ...           ศรีราชา  508638
#
# [22334 rows x 12 columns]

# %%
dataCN[['risk']].dropna().mode().iloc[0,0]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %% [markdown]
# ## [PD] ต่อตาราง แกน Y

# %%
dataKKCN = pd.concat([dataKK,dataCN])
dataKKCN
# Out:
#            No. announce_date  ... district_of_onset new col
# 181        182     18/3/2020  ...             เมือง     181
# 463        464     22/3/2020  ...             เมือง     463
# 1467      1468     30/3/2020  ...             เมือง    1467
# 1971      1972      3/4/2020  ...             เมือง    1971
# 2638      2639     15/4/2020  ...            น้ำพอง    2638
# ...        ...           ...  ...               ...     ...
# 507502  507503     26/7/2021  ...               NaN  507502
# 507627  507628     26/7/2021  ...           บ้านบึง  507627
# 507628  507629     26/7/2021  ...           บ้านบึง  507628
# 507629  507630     26/7/2021  ...           บ้านบึง  507629
# 508638  508639     26/7/2021  ...           ศรีราชา  508638
#
# [25483 rows x 12 columns]

# %%
X = list(set(data_cases['province_of_onset']))
X
# Out:
# [nan,
#  'กาฬสินธุ์',
#  'น่าน',
#  'หนองบัวลำำภู',
#  'ลำปาง',
#  'ระยอง',
#  'สมุทรสาคร',
#  'ูภูเก็ต',
#  'เลย',
#  'นครราชสีมา',
#  'ปัตตานี',
#  'ฉะเชิงเทรา',
#  'นครศรีราชสีมา',
#  'ชุมพร',
#  'นครสววรค์',
#  'อุตรดิตถ์',
#  'นคปฐม',
#  'ปทุมธานี',
#  'อุุดรธาน',
#  'สุราษฎร์ธานี',
#  'มหาสารคาม',
#  'ชลบุุรี',
#  'กาฬสิินธุ์',
#  'ประจวบคีรีขันธ์',
#  'นตรปฐม',
#  'ร้องกวาง',
#  'นครนาชสีมา',
#  'บางกะปิ',
#  'เพรชบุรี',
#  'กระบี่',
#  'นาราธิวาส',
#  'เด่นชัย',
#  'พัทลุง',
#  'ศีรษะเกษ',
#  'ลพบุรี',
#  'กรุงเทพมหานคร',
#  'เมืองน่าน',
#  'นครศรีธรรรมราช',
#  'อุบลราชธานี',
#  'ปัว',
#  'ราชบุรี',
#  'พิษณุโลก',
#  'แม่ฮ่องสอน',
#  'สมุุทรสาคร',
#  'หนองบััวลำภู',
#  'ภูเพียง',
#  'สมุทรปราการ',
#  'อุุดรธานี',
#  'หนองม่วงไข่',
#  'ยโสธร',
#  'นนทบุรี',
#  'สมุุทรปราการ',
#  'สระแก้ว',
#  'พระนครศรีอยุธนา',
#  'ร้อยเอ็ด',
#  'จันทบุรี',
#  'พม่า',
#  'เพชรบูรณ์',
#  'ขอนแก่่น',
#  'สุพรรณบุรี',
#  'จังหวัดร้อยเอ็ด',
#  'นครศรี',
#  'ธารโต',
#  'สมุทปราการ',
#  'อยุธยา',
#  'วังชิ้น',
#  'สมุทสาคร',
#  'อุุตรดิตถ์',
#  'พิจิตร',
#  'ระนอง',
#  'นครประฐม',
#  'เชียงราย',
#  'ยานนาวา',
#  'อุทัยธานี',
#  'พระนครศีอยุธยา',
#  'ลอง',
#  'สถานที่ทำงาน',
#  'นครศรีีธรรมราช',
#  'นราธิวาส',
#  'แพร่',
#  'ตราด',
#  'พระนครศรีอยุธยา',
#  'เชียงใหม่',
#  'บุรีรัมย์',
#  'ปราจีนบุรี',
#  'พระนครศีรอยุธยา',
#  'สมุทราปราการ',
#  'ชัยภูมิ',
#  'ลพบรี',
#  'นครสวรรค์',
#  'สุมทรสาคร',
#  'ภูเก็ต',
#  'กาญจนบุรี',
#  'ประจวบคีรีขันธื',
#  'พระนตรศรีอยุธยา',
#  'ศรีีสะเกษ',
#  'สตูล',
#  'ลำพูน',
#  'อุดรธานีี',
#  'กัมพูชา',
#  'สมุทราสาคร',
#  'สงขขลา',
#  'ปทุุมธานี',
#  'สระบุรี',
#  'ชลบุรี',
#  'ประจวบครีขันธ์',
#  'เวียงสา',
#  'สระบุุรี',
#  'ร้อยเอ็็ด',
#  'อุดรธานี',
#  'ศรีสะเกษ',
#  'ปทุมทานี',
#  'สมุทรสงคราม',
#  'มหาสารคราม',
#  'นครพนม',
#  'ศีรสะเกษ',
#  'สุรินทร์',
#  'ปัตตานี\u200b',
#  'พะเยา',
#  'เพชรบุรี',
#  'หนองคาย',
#  'ลพบุุรี',
#  'ศรีษะเกษ',
#  'สรแก้ว',
#  'นาวัง',
#  'มุกดาหาร',
#  'ยะลา',
#  'ตาก',
#  'สิงห์บุรี',
#  'นครนายก',
#  'สุมุทรสาคร',
#  'อุุทัยธานี',
#  'เวียงจันทร์',
#  'จ.ปัตตานี',
#  'บึงโขงหลง',
#  'สกลนคร',
#  'นคนปฐม',
#  'ชัยนาท',
#  'บึึงกาฬ',
#  'ตรัง',
#  'สุโขทัย',
#  'นครศรีธรรมราช',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'อ่างทอง',
#  'เรือ',
#  'นครศรธรรมาช',
#  'สองแคว',
#  'ปลายพระยา',
#  'สุทรปราการ',
#  'กาฬสินธิ์',
#  'มาเลเซีย',
#  'กาฬสินธ์ุ',
#  'ชััยภูมิ',
#  'เพชบุรี',
#  'สงขลา\u200b',
#  'สมุุทรสงคราม',
#  'อำนาจเจริญ',
#  'บ้านหลวง',
#  'สูงเม่น',
#  'หนองบัวลำภู',
#  'พังงา',
#  'นครปฐม',
#  'ปทุมธานีี',
#  'สมุุทสาคร',
#  'สมทรสาคร',
#  'สงขลา',
#  'สุมุทรปราการ',
#  'สอง',
#  'สุุราษฎร์ธานี',
#  'อุบลราขธานี',
#  'เมือง',
#  'นครราชธสีมา',
#  'ไม่ระบุ',
#  'หนองบัวลำภูู',
#  'บึงกาฬ',
#  'พระนครศรียุธยา',
#  'เพรบุรี',
#  'ร้้อยเอ็ด',
#  'นนทุบรี',
#  'สมุทรปาการ',
#  'สมุทสงคราม',
#  'ชุุมพร',
#  'พระนครศรีอยุทธยา',
#  'ร้อยเอ้ด']

# %%
dataCN = data_cases[data_cases['province_of_onset']==X[0]]

# %%
dataCN
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, Unit, nationality, province_of_isolation, risk, province_of_onset, district_of_onset, new col]
# Index: []

# %%
prov_list = list()
for e_province in list(set(data_cases['province_of_onset']))[1:]:
    print(e_province)
    dataCN = data_cases[data_cases['province_of_onset']==e_province]
    dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
    prov_list.append(dataCN) ## 
dataALL = pd.concat(prov_list)
# Out:
# กาฬสินธุ์
# น่าน
# หนองบัวลำำภู
# ลำปาง
# ระยอง
# สมุทรสาคร
# ูภูเก็ต
# เลย
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# นครราชสีมา
# ปัตตานี
# ฉะเชิงเทรา
# นครศรีราชสีมา
# ชุมพร
# นครสววรค์
# อุตรดิตถ์
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# นคปฐม
# ปทุมธานี
# อุุดรธาน
# สุราษฎร์ธานี
# มหาสารคาม
# ชลบุุรี
# กาฬสิินธุ์
# ประจวบคีรีขันธ์
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# นตรปฐม
# ร้องกวาง
# นครนาชสีมา
# บางกะปิ
# เพรชบุรี
# กระบี่
# นาราธิวาส
# เด่นชัย
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# พัทลุง
# ศีรษะเกษ
# ลพบุรี
# กรุงเทพมหานคร
# เมืองน่าน
# นครศรีธรรรมราช
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# อุบลราชธานี
# ปัว
# ราชบุรี
# พิษณุโลก
# แม่ฮ่องสอน
# สมุุทรสาคร
# หนองบััวลำภู
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ภูเพียง
# สมุทรปราการ
# อุุดรธานี
# หนองม่วงไข่
# ยโสธร
# นนทบุรี
# สมุุทรปราการ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สระแก้ว
# พระนครศรีอยุธนา
# ร้อยเอ็ด
# จันทบุรี
# พม่า
# เพชรบูรณ์
# ขอนแก่่น
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สุพรรณบุรี
# จังหวัดร้อยเอ็ด
# นครศรี
# ธารโต
# สมุทปราการ
# อยุธยา
# วังชิ้น
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สมุทสาคร
# อุุตรดิตถ์
# พิจิตร
# ระนอง
# นครประฐม
# เชียงราย
# ยานนาวา
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# อุทัยธานี
# พระนครศีอยุธยา
# ลอง
# สถานที่ทำงาน
# นครศรีีธรรมราช
# นราธิวาส
# แพร่
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ตราด
# พระนครศรีอยุธยา
# เชียงใหม่
# บุรีรัมย์
# ปราจีนบุรี
# พระนครศีรอยุธยา
# สมุทราปราการ
# ชัยภูมิ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ลพบรี
# นครสวรรค์
# สุมทรสาคร
# ภูเก็ต
# กาญจนบุรี
# ประจวบคีรีขันธื
# พระนตรศรีอยุธยา
# ศรีีสะเกษ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สตูล
# ลำพูน
# อุดรธานีี
# กัมพูชา
# สมุทราสาคร
# สงขขลา
# ปทุุมธานี
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สระบุรี
# ชลบุรี
# ประจวบครีขันธ์
# เวียงสา
# สระบุุรี
# ร้อยเอ็็ด
# อุดรธานี
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ศรีสะเกษ
# ปทุมทานี
# สมุทรสงคราม
# มหาสารคราม
# นครพนม
# ศีรสะเกษ
# สุรินทร์
# ปัตตานี​
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# พะเยา
# เพชรบุรี
# หนองคาย
# ลพบุุรี
# ศรีษะเกษ
# สรแก้ว
# นาวัง
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ...
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# นครศรีธรรมราช
# กำแพงเพชร
# ขอนแก่น
# อ่างทอง
# เรือ
# นครศรธรรมาช
# สองแคว
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ปลายพระยา
# สุทรปราการ
# กาฬสินธิ์
# มาเลเซีย
# กาฬสินธ์ุ
# ชััยภูมิ
# เพชบุรี
# สงขลา​
# สมุุทรสงคราม
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# อำนาจเจริญ
# บ้านหลวง
# สูงเม่น
# หนองบัวลำภู
# พังงา
# นครปฐม
# ปทุมธานีี
# สมุุทสาคร
# สมทรสาคร
# สงขลา
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สุมุทรปราการ
# สอง
# สุุราษฎร์ธานี
# อุบลราขธานี
# เมือง
# นครราชธสีมา
# ไม่ระบุ
# หนองบัวลำภูู
# บึงกาฬ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# พระนครศรียุธยา
# เพรบุรี
# ร้้อยเอ็ด
# นนทุบรี
# สมุทรปาการ
# สมุทสงคราม
# ชุุมพร
# พระนครศรีอยุทธยา
# ร้อยเอ้ด
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 187        188     18/3/2020  ...           ยางตลาด     187
# 883        884     25/3/2020  ...              นามน     883
# 1885      1886      3/4/2020  ...           ฆ้องชัย    1885
# 24850    24851     17/2/2021  ...            ร่องคำ   24850
# 28750    28751     29/3/2021  ...           ยางตลาด   28750
# ...        ...           ...  ...               ...     ...
# 388293  388294     17/7/2021  ...               NaN  388293
# 388315  388316     17/7/2021  ...               NaN  388315
# 399906  399907     18/7/2021  ...          บางปะอิน  399906
# 505837  505838     26/7/2021  ...            โพนทอง  505837
# 505925  505926     26/7/2021  ...           เสลภูมิ  505925
#
# [447605 rows x 12 columns]

# %%
datamissingonset = data_cases[pd.isna(data_cases['province_of_onset'])]
datamissingonset
# Out:
#            No. announce_date  ... district_of_onset new col
# 415        416     22/3/2020  ...               NaN     415
# 530        531     22/3/2020  ...               NaN     530
# 556        557     22/3/2020  ...               NaN     556
# 577        578     22/3/2020  ...               NaN     577
# 589        590     22/3/2020  ...               NaN     589
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [65017 rows x 12 columns]

# %%
datamissingonset[['risk']] = datamissingonset[['risk']].fillna(datamissingonset[['risk']].dropna().mode().iloc[0,0])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dataALL = pd.concat([dataALL,datamissingonset])

# %%
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 187        188     18/3/2020  ...           ยางตลาด     187
# 883        884     25/3/2020  ...              นามน     883
# 1885      1886      3/4/2020  ...           ฆ้องชัย    1885
# 24850    24851     17/2/2021  ...            ร่องคำ   24850
# 28750    28751     29/3/2021  ...           ยางตลาด   28750
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
dataALL = dataALL.sort_values(by='No.')
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL.keys()
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset', 'new col'],
#       dtype='object')

# %% [markdown]
# ## การทำงานกับ Datetime-Timestamp
