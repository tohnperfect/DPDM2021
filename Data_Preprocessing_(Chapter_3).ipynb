# %% [markdown]
# <a href="https://colab.research.google.com/github/tohnperfect/DPDM2021/blob/main/Data_Preprocessing_(Chapter_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # ทำงานกับข้อมูลลักษณะ ตาราง

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DPDM2021_DATA'
data_cases = pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.loc[data_cases['announce_date']=='26/7/2021'].index
# Out:
# Int64Index([497246, 497247, 497248, 497249, 497250, 497251, 497252, 497253,
#             497254, 497255,
#             ...
#             512612, 512613, 512614, 512615, 512616, 512617, 512618, 512619,
#             512620, 512621],
#            dtype='int64', length=15376)

# %% [markdown]
# # ชี้ข้อมูลในตาราง

# %%
data_cases['risk']
# Out:
# 0         คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         คนต่างชาติเดินทางมาจากต่างประเทศ
#                         ...
# 512617                    ทัณฑสถาน/เรือนจำ
# 512618                    ทัณฑสถาน/เรือนจำ
# 512619                    ทัณฑสถาน/เรือนจำ
# 512620                    ทัณฑสถาน/เรือนจำ
# 512621                    ทัณฑสถาน/เรือนจำ
# Name: risk, Length: 512622, dtype: object

# %%
data_cases[['risk','age']]
# Out:
#                                     risk   age
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ  61.0
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ  74.0
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ  73.0
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ  68.0
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ  66.0
# ...                                  ...   ...
# 512617                  ทัณฑสถาน/เรือนจำ   NaN
# 512618                  ทัณฑสถาน/เรือนจำ   NaN
# 512619                  ทัณฑสถาน/เรือนจำ   NaN
# 512620                  ทัณฑสถาน/เรือนจำ   NaN
# 512621                  ทัณฑสถาน/เรือนจำ   NaN
#
# [512622 rows x 2 columns]

# %%
data_cases['risk'][666]
# Out:
# 'สนามมวย'

# %% [markdown]
# # ชี้โดยใช้ .iloc[] (แปลงมุมมองให้เป็น matrix)

# %%
data_cases.iloc[4,4]
# Out:
# 66.0

# %%
data_cases.iloc[-50:,:]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 512572  512573     26/7/2021  ...               NaN               NaN
# 512573  512574     26/7/2021  ...               NaN               NaN
# 512574  512575     26/7/2021  ...               NaN               NaN
# 512575  512576     26/7/2021  ...               NaN               NaN
# 512576  512577     26/7/2021  ...               NaN               NaN
# 512577  512578     26/7/2021  ...               NaN               NaN
# 512578  512579     26/7/2021  ...               NaN               NaN
# 512579  512580     26/7/2021  ...               NaN               NaN
# 512580  512581     26/7/2021  ...               NaN               NaN
# 512581  512582     26/7/2021  ...               NaN               NaN
# 512582  512583     26/7/2021  ...               NaN               NaN
# 512583  512584     26/7/2021  ...               NaN               NaN
# 512584  512585     26/7/2021  ...               NaN               NaN
# 512585  512586     26/7/2021  ...               NaN               NaN
# 512586  512587     26/7/2021  ...               NaN               NaN
# 512587  512588     26/7/2021  ...               NaN               NaN
# 512588  512589     26/7/2021  ...               NaN               NaN
# 512589  512590     26/7/2021  ...               NaN               NaN
# 512590  512591     26/7/2021  ...               NaN               NaN
# 512591  512592     26/7/2021  ...               NaN               NaN
# 512592  512593     26/7/2021  ...               NaN               NaN
# 512593  512594     26/7/2021  ...               NaN               NaN
# 512594  512595     26/7/2021  ...               NaN               NaN
# 512595  512596     26/7/2021  ...               NaN               NaN
# 512596  512597     26/7/2021  ...               NaN               NaN
# 512597  512598     26/7/2021  ...               NaN               NaN
# 512598  512599     26/7/2021  ...               NaN               NaN
# 512599  512600     26/7/2021  ...               NaN               NaN
# 512600  512601     26/7/2021  ...               NaN               NaN
# 512601  512602     26/7/2021  ...               NaN               NaN
# 512602  512603     26/7/2021  ...               NaN               NaN
# 512603  512604     26/7/2021  ...               NaN               NaN
# 512604  512605     26/7/2021  ...               NaN               NaN
# 512605  512606     26/7/2021  ...               NaN               NaN
# 512606  512607     26/7/2021  ...               NaN               NaN
# 512607  512608     26/7/2021  ...               NaN               NaN
# 512608  512609     26/7/2021  ...               NaN               NaN
# 512609  512610     26/7/2021  ...               NaN               NaN
# 512610  512611     26/7/2021  ...               NaN               NaN
# 512611  512612     26/7/2021  ...               NaN               NaN
# 512612  512613     26/7/2021  ...               NaN               NaN
# 512613  512614     26/7/2021  ...               NaN               NaN
# 512614  512615     26/7/2021  ...               NaN               NaN
# 512615  512616     26/7/2021  ...               NaN               NaN
# 512616  512617     26/7/2021  ...               NaN               NaN
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [50 rows x 11 columns]

# %%
data_cases.iloc[-50:,[3,6,8]]
# Out:
#          sex nationality              risk
# 512572  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512573  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512574  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512575  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512576  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512577  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512578  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512579  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512580  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512581  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512582  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512583  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512584  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512585  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512586  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512587  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512588  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512589  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512590  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512591  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512592  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512593  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512594  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512595  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512596  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512597  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512598   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512599  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512600  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512601  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512602  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512603  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512604  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512605  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512606  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512607  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512608  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512609  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512610  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512611  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512612  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 512613   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512614   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512615   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512616   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512617   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512618   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512619   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512620   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 512621   ชาย         NaN  ทัณฑสถาน/เรือนจำ

# %% [markdown]
# # Descriptive Statistics of Data

# %%
data_cases.describe()
# Out:
#                  No.            age
# count  512622.000000  462839.000000
# mean   256311.500000      35.529470
# std    147981.369183      16.153885
# min         1.000000       1.000000
# 25%    128156.250000      25.000000
# 50%    256311.500000      34.000000
# 75%    384466.750000      46.000000
# max    512622.000000     108.000000

# %% [markdown]
# # Missing Value
#
#
#
# *   Null
# *   NaN = Not a Number
# *   NA = Not available

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull()
# Out:
#           No.  announce_date  ...  province_of_onset  district_of_onset
# 0       False          False  ...              False               True
# 1       False          False  ...              False               True
# 2       False          False  ...              False              False
# 3       False          False  ...              False               True
# 4       False          False  ...              False               True
# ...       ...            ...  ...                ...                ...
# 512617  False          False  ...               True               True
# 512618  False          False  ...               True               True
# 512619  False          False  ...               True               True
# 512620  False          False  ...               True               True
# 512621  False          False  ...               True               True
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull().any()  # .any() คือ Or ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases.isnull().any().any()
# Out:
# True

# %%
data_cases.isnull().all()  # .all() คือ and ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# # Handling Missing Value 1 (ลบค่า missing )

# %%
data_cases.shape
# Out:
# (512622, 11)

# %%
data_cases_M1 = data_cases.dropna()

# %%
data_cases_M1.shape
# Out:
# (362205, 11)

# %% [markdown]
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data

# %%
print('size before drop = ',len(data_cases))
print('size after drop = ', len(data_cases_M1))
print('we lost ', ((len(data_cases)-len(data_cases_M1))/len(data_cases))*100, '% of data')
# Out:
# size before drop =  512622
# size after drop =  362205
# we lost  29.342673548930794 % of data

# %%
print(f'size before drop = {len(data_cases)}')
print('size after drop = ', len(data_cases_M1))
print(f'we lost {((len(data_cases)-len(data_cases_M1))/len(data_cases))*100:.2f}% of data')
# Out:
# size before drop = 512622
# size after drop =  362205
# we lost 29.34% of data

# %% [markdown]
# ## Handling Missing Value 1.5 (ลบค่า missing เฉพาะใน column ที่เราสนใจ)

# %%
data_cases_M15 = data_cases.dropna(subset=['Notified date', 'sex', 'age'])

# %%
data_cases_M15.shape
# Out:
# (449552, 11)

# %% [markdown]
# HW
#
# ```print``` ของ missing 1.5
#
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data
#
# now we have x% more data than handling_missing1

# %% [markdown]
# ## Handling Missing Value 2 แทนด้วยค่าที่เหมาะสมหรือสร้าง class ใหม่

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases['age'].mean(skipna=False) ## ถ้า function ไม่ได้ป้องกัน data ที่มี missing ไว้
# Out:
# nan

# %%
data_cases[['Notified date']] = data_cases[['Notified date']].fillna('99/99/9999')

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ### ดู column unit

# %%
data_cases['Unit']
# Out:
# 0          ปี
# 1          ปี
# 2          ปี
# 3          ปี
# 4          ปี
#          ...
# 512617    NaN
# 512618    NaN
# 512619    NaN
# 512620    NaN
# 512621    NaN
# Name: Unit, Length: 512622, dtype: object

# %%
set(data_cases['Unit']) ## หา unique values
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %% [markdown]
# ## [PD] วิธีเลือก record โดยการกำหนดค่า

# %%
data_cases[data_cases['Unit']=='วัน']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 19706    19707      2/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 23791    23792     10/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 40962    40963     18/4/2021  ...        นครราชสีมา           เสิงสาง
# 57747    57748     27/4/2021  ...               NaN               NaN
# 72457    72458      4/5/2021  ...     กรุงเทพมหานคร            สายไหม
# ...        ...           ...  ...               ...               ...
# 443474  443475     22/7/2021  ...            นครปฐม           สามพราน
# 474582  474583     24/7/2021  ...        ฉะเชิงเทรา           บางปะกง
# 477365  477366     24/7/2021  ...      สุราษฎร์ธานี            พุนพิน
# 488901  488902     25/7/2021  ...            ชลบุรี          บางละมุง
# 504780  504781     26/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
#
# [64 rows x 11 columns]

# %%
data_cases[data_cases['Unit']==' วัน']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 138721  138722     27/5/2021  ...       สมุทรปราการ            บางพลี
#
# [1 rows x 11 columns]

# %% [markdown]
# ```python
# data_frame[list_of_logics] #list_of_logics มีขนาดเท่ากับจำนวน record ของ data_frame
# ```

# %%
data_cases['Unit']=='วัน'  # list_of_logics
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 512617    False
# 512618    False
# 512619    False
# 512620    False
# 512621    False
# Name: Unit, Length: 512622, dtype: bool

# %%
data_cases[data_cases['Unit']=='วัน'].sort_values(by='age')
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 339653  339654     12/7/2021  ...       สมุทรปราการ            บางพลี
# 375821  375822     16/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
# 367305  367306     15/7/2021  ...       สมุทรปราการ  เมืองสมุทรปราการ
# 377872  377873     16/7/2021  ...     กรุงเทพมหานคร               NaN
# 409055  409056     19/7/2021  ...       สมุทรปราการ         พระประแดง
# ...        ...           ...  ...               ...               ...
# 19706    19707      2/2/2021  ...         สมุทรสาคร    เมืองสมุทรสาคร
# 321015  321016     10/7/2021  ...       สมุทรปราการ  เมืองสมุทรปราการ
# 291137  291138      6/7/2021  ...       สมุทรปราการ    พระสมุทรเจดีย์
# 443474  443475     22/7/2021  ...            นครปฐม           สามพราน
# 285988  285989      5/7/2021  ...            ชลบุรี           ศรีราชา
#
# [64 rows x 11 columns]

# %% [markdown]
# Quiz 10
# หา records ต่อไปนี้
#
# ~records ที่ กักตัวที่ขอนแก่น~ Oil
#
# ~records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร~ Kie
#
# ~records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม~ Kie
#
# ~records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่~ Nicha

# %% [markdown]
# records ที่ กักตัวที่ขอนแก่น

# %%
data_cases[data_cases['province_of_isolation']=='ขอนแก่น']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 505598  505599     26/7/2021  ...           ขอนแก่น           ภูเวียง
# 505599  505600     26/7/2021  ...           ขอนแก่น           ภูเวียง
# 511809  511810     26/7/2021  ...               NaN               NaN
# 511810  511811     26/7/2021  ...               NaN               NaN
# 511811  511812     26/7/2021  ...               NaN               NaN
#
# [3707 rows x 11 columns]

# %% [markdown]
# records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร

# %%
data_cases[(data_cases['province_of_isolation']=='ขอนแก่น') | (data_cases['province_of_isolation']=='นครราชสีมา') |
           (data_cases['province_of_isolation']=='อุดรธานี')]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 189        190     18/3/2020  ...        นครราชสีมา             พิมาย
# 207        208     18/3/2020  ...     กรุงเทพมหานคร               NaN
# 212        213     18/3/2020  ...        นครราชสีมา       วังน้ำเขียว
# 284        285     20/3/2020  ...        นครราชสีมา   เมืองนครราชสีมา
# ...        ...           ...  ...               ...               ...
# 507218  507219     26/7/2021  ...               NaN               NaN
# 507219  507220     26/7/2021  ...               NaN               NaN
# 511809  511810     26/7/2021  ...               NaN               NaN
# 511810  511811     26/7/2021  ...               NaN               NaN
# 511811  511812     26/7/2021  ...               NaN               NaN
#
# [10539 rows x 11 columns]

# %% [markdown]
# records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม

# %%
data_cases[(data_cases['province_of_onset']=='กรุงเทพมหานคร') & (data_cases['sex']=='หญิง')]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5            6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6            7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 511560  511561     26/7/2021  ...     กรุงเทพมหานคร            ธนบุรี
# 511562  511563     26/7/2021  ...     กรุงเทพมหานคร         คลองสามวา
# 511566  511567     26/7/2021  ...     กรุงเทพมหานคร       บางขุนเทียน
# 511574  511575     26/7/2021  ...     กรุงเทพมหานคร         ลาดกระบัง
# 511577  511578     26/7/2021  ...     กรุงเทพมหานคร            บางบอน
#
# [58896 rows x 11 columns]

# %% [markdown]
# records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่

# %%
data_cases[(data_cases['province_of_isolation']=='เชียงใหม่') & 
           (data_cases['sex']=='ชาย') &
           (data_cases['age']>=18) &
           (data_cases['age']<=22)].sort_values(by='age')
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 37385    37386     15/4/2021  ...         เชียงใหม่            แม่ออน
# 38887    38888     16/4/2021  ...         เชียงใหม่         ดอยสะเก็ด
# 81287    81288      9/5/2021  ...         เชียงใหม่           สันทราย
# 47078    47079     22/4/2021  ...         เชียงใหม่            แม่ริม
# 78869    78870      8/5/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# ...        ...           ...  ...               ...               ...
# 34470    34471     13/4/2021  ...         เชียงใหม่               NaN
# 34445    34446     13/4/2021  ...         เชียงใหม่               NaN
# 34439    34440     13/4/2021  ...         เชียงใหม่               NaN
# 34506    34507     13/4/2021  ...         เชียงใหม่               NaN
# 497302  497303     26/7/2021  ...         เชียงใหม่             หางดง
#
# [411 rows x 11 columns]

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data_cases['Unit'].dropna())
# Out:
# (array([4.61483e+05, 0.00000e+00, 1.43600e+03, 0.00000e+00, 0.00000e+00,
#         6.40000e+01, 0.00000e+00, 3.90000e+01, 0.00000e+00, 1.00000e+00]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
data_cases[['Unit']] = data_cases[['Unit']].fillna('ปี')

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['nationality']] = data_cases[['nationality']].fillna('ไทย?')

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# ## Handling Missing Value 3 แทนด้วยค่าด้วยค่ากลาง

# %%
data_cases[['age']] = data_cases[['age']].fillna(data_cases['age'].mean())

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['sex']].dropna().mode()
# Out:
#    sex
# 0  ชาย

# %%
data_cases[['sex']].dropna().mode().iloc[0,0]
# Out:
# 'ชาย'

# %%
data_cases[['sex']] = data_cases[['sex']].fillna(data_cases[['sex']].dropna().mode().iloc[0,0])
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ## Loop [PD]

# %%
for i in range(10):
    print(data_cases.iloc[i,:])
    print('------------------new line---------------')
# Out:
# No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    61
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object
# ------------------new line---------------
# No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    74
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 1, dtype: object
# ------------------new line---------------
# No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# Name: 2, dtype: object
# ------------------new line---------------
# No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    68
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 3, dtype: object
# ------------------new line---------------
# No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    66
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 4, dtype: object
# ------------------new line---------------
# No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    33
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 5, dtype: object
# ------------------new line---------------
# No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    57
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 6, dtype: object
# ------------------new line---------------
# No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# Name: 7, dtype: object
# ------------------new line---------------
# No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    63
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 8, dtype: object
# ------------------new line---------------
# No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    28
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# Name: 9, dtype: object
# ------------------new line---------------

# %%
for record in data_cases.iloc[:10,:].iterrows():
    print(record)
    print('------------------new line---------------')
# Out:
# (0, No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    61
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object)
# ------------------new line---------------
# (1, No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    74
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 1, dtype: object)
# ------------------new line---------------
# (2, No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# Name: 2, dtype: object)
# ------------------new line---------------
# (3, No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    68
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 3, dtype: object)
# ------------------new line---------------
# (4, No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    66
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 4, dtype: object)
# ------------------new line---------------
# (5, No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    33
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 5, dtype: object)
# ------------------new line---------------
# (6, No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    57
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 6, dtype: object)
# ------------------new line---------------
# (7, No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    73
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# Name: 7, dtype: object)
# ------------------new line---------------
# (8, No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                    63
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 8, dtype: object)
# ------------------new line---------------
# (9, No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                    28
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# Name: 9, dtype: object)
# ------------------new line---------------

# %% [markdown]
# ## เราสามารถกำหนดค่าให้กับตารางทีละ column หรือสร้าง
# ## column ใหม่ให้กับตาราง ได้โดยใช้ list ที่มีจำนวนเท่ากับจำนวน record

# %%
data_cases['new col'] = list(range(data_cases.shape[0]))

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %% [markdown]
# # แก้ missing ใน province_of_isolation เติมค่าของ onset ใน isolation ก่อนจะเติมค่า mode

# %%
new_p_iso = list()

for row in data_cases.iterrows():
    if pd.isna(row[1]['province_of_isolation']):
        if pd.isna(row[1]['province_of_onset']) == False:
            new_p_iso.append(row[1]['province_of_onset'])
        else:
            new_p_iso.append(data_cases[['province_of_isolation']].dropna().mode().iloc[0,0])
    else:
        new_p_iso.append(row[1]['province_of_isolation'])

# %%
len(new_p_iso)
# Out:
# 512622

# %%
data_cases['province_of_isolation'] = new_p_iso

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
data_cases2 = pd.read_csv(os.path.join(path,'confirmed-cases.csv'))

# %%
data_cases2[pd.isna(data_cases2['province_of_isolation'])]
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 39        40     26/2/2020  ...     กรุงเทพมหานคร          ดอนเมือง
# 40        41     28/2/2020  ...           นนทบุรี               NaN
# 41        42     29/2/2020  ...     กรุงเทพมหานคร        วังทองหลาง
# 42        43      2/3/2020  ...     กรุงเทพมหานคร              สาทร
# 140      141     16/3/2020  ...     กรุงเทพมหานคร               NaN
# ...      ...           ...  ...               ...               ...
# 40815  40816     18/4/2021  ...               NaN               NaN
# 40816  40817     18/4/2021  ...               NaN               NaN
# 40817  40818     18/4/2021  ...               NaN               NaN
# 40830  40831     18/4/2021  ...               NaN               NaN
# 40831  40832     18/4/2021  ...               NaN               NaN
#
# [508 rows x 11 columns]

# %%
data_cases[pd.isna(data_cases2['province_of_isolation'])]
# Out:
#          No. announce_date  ... district_of_onset new col
# 39        40     26/2/2020  ...          ดอนเมือง      39
# 40        41     28/2/2020  ...               NaN      40
# 41        42     29/2/2020  ...        วังทองหลาง      41
# 42        43      2/3/2020  ...              สาทร      42
# 140      141     16/3/2020  ...               NaN     140
# ...      ...           ...  ...               ...     ...
# 40815  40816     18/4/2021  ...               NaN   40815
# 40816  40817     18/4/2021  ...               NaN   40816
# 40817  40818     18/4/2021  ...               NaN   40817
# 40830  40831     18/4/2021  ...               NaN   40830
# 40831  40832     18/4/2021  ...               NaN   40831
#
# [508 rows x 12 columns]

# %% [markdown]
# ## Handling Missing Value 4 แทนด้วยค่าด้วยค่ากลางของกลุ่ม

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
risk_list = list(set(data_cases['risk']))
print(risk_list)
# Out:
# [nan, 'สถานบันเทิง', 'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต', 'ACF สีลม', 'Cluster ทัณฑสถานโรงพยาบาลราชทัณฑ์', 'Cluster โรงงาน  Big Star', 'คนต่างชาติเดินทางมาจากต่างประเทศ', 'สัมผัสผู้ป่วยยืนยัน \n อยู่ระหว่างสอบสวน', 'พิธีกรรมทางศาสนา', 'ACF เคหะหลักสี่', 'Cluster จันทบุรี', 'เดินทางมาจากพื้นที่เสี่ยงที่มีการระบาดของโรค', 'Cluster เรือนจำพิเศษมีนบุรี', 'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานครมหานคร', 'Cluster งานมอเตอร์ โชว์', 'ศูนย์กักกัน ผู้ต้องกัก', 'Cluster ปากช่อง', 'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน', 'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน', 'สัมผัสในสถานพยาบาล', 'อยู่ระหว่างสอบสวนโรค', 'ทัณฑสถาน/เรือนจำ', 'บุคลากรด้านการแพทย์และสาธารณสุข', 'Cluster New Jazz กรุงเทพมหานคร', 'Cluster คลองเตย', 'สัมผัสผู้ติดเชื้อยืนยัน อยู่ระหว่างสอบสวน', 'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน', 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้', 'Cluster เรือนจำพิเศษธนบุรี', 'สถานที่ทำงาน', 'Cluster บางแค', 'Cluster ทันฑสถานบำบัดพิเศษกลาง', 'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)', 'ผู้ป่วย กรุงเทพมหานคร', 'เดินทางมาจากพื้นที่จังหวัดเสี่ยง', 'ร้านอาหาร', 'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar', 'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)', 'ระบุไม่ได้', 'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น', 'Cluster The Lounge Salaya', 'Cluster สมุทรปราการ GRP Hightech', 'เดินทางมาจากพื้นที่มีการระบาดของโรค', 'Cluster จันทบุรี (ชาวกินี)', 'Cluster ตลาดบางแค', 'Cluster โรงงาน QPP ประจวบฯ', 'ตรวจก่อนทำหัตถการ', 'Cluster ชลบุรี', 'อยู่ระหว่างการสอบสวน', 'ACF รองเมือง', 'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน', 'สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)', 'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)', 'ACF สนามกีฬาไทย-ญี่ปุ่น', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ', 'Cluster ตลาดบางแค/คลองขวาง', 'สัมผัสผู้ป่วยยืนยัน', 'Cluster สมุทรปราการ ตลาดเคหะบางพลี', 'Cluster โรงงานทำขนม บางขุนเทียน', 'Cluster ผับ Thonglor', 'ระหว่างการสอบสวนโรค', 'Cluster บ่อนเทพารักษ์', 'อื่น', 'รับจ้างขนของที่ตลาดท่ายาง', 'Cluster สมุทรสาคร', 'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน', '2.สัมผัสผู้ติดเชื้อ', 'ผู้ติดเชื้อในประเทศ', 'สัมผัสผู้เดินทางจากต่างประเทศ', 'Cluster โรงงาน Big Star', 'สนามมวย', 'ACF สนามกีฬาธูปะเตมีย์', 'Cluster ตลาดพรพัฒน์', 'Cluster ตลาดบางพลี', 'Cluster เรือนจำกลางคลองเปรม', 'Cluster ตราด ', 'Cluster ชลบุรี บริษัทไดกิ้น', 'สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน', 'SHUI', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ', "Cluster Memory 90's กรุงเทพมหานคร", 'Cluster ตราด', 'Refer in', 'Cluster มหาสารคาม', 'ค้นหาเชิงรุก', 'Cluster ระยอง วิริยะประกันภัย', 'Cluster ตลาดนนทบุรี', 'Cluster บ่อนไก่อ่างทอง', 'ตรวจสุขภาพแรงงานต่างด้าว', 'อยู่ระหว่างการสอบสวน\n', 'ไปยังพื้นที่ที่มีการระบาด', 'Cluster สถานบันเทิงย่านทองหล่อ', 'Cluster ทัณฑสถานหญิงกลาง', 'สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน', 'ปอดอักเสบ Pneumonia', 'Cluster จนท. สนามบินสุวรรณภูมิ', 'ผับหัวหิน', 'ไปแหล่งชุมชน/สถานที่คนหนาแน่น', 'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า', 'ระหว่างสอบสวน', 'สัมผัสผู้ป่วยที่ติดโควิด', 'Cluster บ่อนพัทยา/ชลบุรี', 'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว', 'Cluster เรือนจำพิเศษกรุงเทพ', 'อื่นๆ', 'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน', 'ผู้ป่วย PUI', 'รอประสาน', 'อยุ่ระหว่างสอบสวน', 'Cluster จันทบุรี (ชาวกินี )', 'อยู่ระหว่างสอบสวน', 'State Quarantine', 'Cluster โรงงาน standard can', 'Cluster Icon siam', 'Cluster กรุงเทพมหานคร. คลองเตย', 'Cluster บริษัทศรีสวัสดิ์', 'Cluster ห้างแสงทอง (สายล่าง)', 'อาศัย/เดินทางไปในพื้นที่ที่มีการระบาด', 'Cluster ตลาดสี่มุมเมือง', 'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)', 'Cluster ชลบุรี โรงเบียร์ 90', 'Sandbox', 'คนไทยเดินทางมาจากต่างประเทศ', 'ปอดอักเสบ (Pneumonia)', 'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร.', 'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า', 'คนไทยเดินทางกลับจากต่างประเทศ', 'ตลาด', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ', 'Cluster ระยอง', 'คนไทยมาจากพื้นที่เสี่ยง', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ']

# %% [markdown]
# ทำของขอนแก่น

# %%
dataKK = data_cases[data_cases['province_of_onset']=='ขอนแก่น']

# %%
dataKK[['risk']] = dataKK[['risk']].fillna(dataKK[['risk']].dropna().mode().iloc[0,0])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dataKK
# Out:
#            No. announce_date  ... district_of_onset new col
# 181        182     18/3/2020  ...             เมือง     181
# 463        464     22/3/2020  ...             เมือง     463
# 1467      1468     30/3/2020  ...             เมือง    1467
# 1971      1972      3/4/2020  ...             เมือง    1971
# 2638      2639     15/4/2020  ...            น้ำพอง    2638
# ...        ...           ...  ...               ...     ...
# 507541  507542     26/7/2021  ...               NaN  507541
# 507542  507543     26/7/2021  ...               NaN  507542
# 507543  507544     26/7/2021  ...               NaN  507543
# 507544  507545     26/7/2021  ...               NaN  507544
# 507546  507547     26/7/2021  ...               NaN  507546
#
# [3149 rows x 12 columns]

# %%
dataKK[['risk']].dropna().mode().iloc[0,0]
# Out:
# 'ทัณฑสถาน/เรือนจำ'

# %%
dataKK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
dataCN = data_cases[data_cases['province_of_onset']=='ชลบุรี']

# %%
dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dataCN
# Out:
#            No. announce_date  ... district_of_onset new col
# 31          32      8/2/2020  ...               NaN      31
# 43          44      5/3/2020  ...           ศรีราชา      43
# 44          45      5/3/2020  ...               NaN      44
# 154        155     17/3/2020  ...             เมือง     154
# 222        223     19/3/2020  ...               NaN     222
# ...        ...           ...  ...               ...     ...
# 507502  507503     26/7/2021  ...               NaN  507502
# 507627  507628     26/7/2021  ...           บ้านบึง  507627
# 507628  507629     26/7/2021  ...           บ้านบึง  507628
# 507629  507630     26/7/2021  ...           บ้านบึง  507629
# 508638  508639     26/7/2021  ...           ศรีราชา  508638
#
# [22334 rows x 12 columns]

# %%
dataCN[['risk']].dropna().mode().iloc[0,0]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %% [markdown]
# ## [PD] ต่อตาราง แกน Y

# %%
dataKKCN = pd.concat([dataKK,dataCN])
dataKKCN
# Out:
#            No. announce_date  ... district_of_onset new col
# 181        182     18/3/2020  ...             เมือง     181
# 463        464     22/3/2020  ...             เมือง     463
# 1467      1468     30/3/2020  ...             เมือง    1467
# 1971      1972      3/4/2020  ...             เมือง    1971
# 2638      2639     15/4/2020  ...            น้ำพอง    2638
# ...        ...           ...  ...               ...     ...
# 507502  507503     26/7/2021  ...               NaN  507502
# 507627  507628     26/7/2021  ...           บ้านบึง  507627
# 507628  507629     26/7/2021  ...           บ้านบึง  507628
# 507629  507630     26/7/2021  ...           บ้านบึง  507629
# 508638  508639     26/7/2021  ...           ศรีราชา  508638
#
# [25483 rows x 12 columns]

# %%
X = list(set(data_cases['province_of_onset']))
X
# Out:
# [nan,
#  'นครศรีธรรมราช',
#  'นครราชสีมา',
#  'อ่างทอง',
#  'นคนปฐม',
#  'สมุุทรสงคราม',
#  'กาฬสินธุ์',
#  'สุโขทัย',
#  'สิงห์บุรี',
#  'สมุทปราการ',
#  'บึึงกาฬ',
#  'สระบุรี',
#  'อุตรดิตถ์',
#  'ธารโต',
#  'ปัตตานี\u200b',
#  'พังงา',
#  'สระแก้ว',
#  'บึงกาฬ',
#  'ประจวบคีรีขันธ์',
#  'ปทุุมธานี',
#  'สระบุุรี',
#  'กาญจนบุรี',
#  'แพร่',
#  'สถานที่ทำงาน',
#  'ชััยภูมิ',
#  'สมุทรสาคร',
#  'ประจวบคีรีขันธื',
#  'จังหวัดร้อยเอ็ด',
#  'ศีรสะเกษ',
#  'พะเยา',
#  'สงขขลา',
#  'สมุทรสงคราม',
#  'กระบี่',
#  'ศรีีสะเกษ',
#  'หนองบัวลำำภู',
#  'อุุทัยธานี',
#  'แม่ฮ่องสอน',
#  'ลพบุุรี',
#  'นครนาชสีมา',
#  'ตาก',
#  'เชียงราย',
#  'สุราษฎร์ธานี',
#  'นครราชธสีมา',
#  'นคปฐม',
#  'นครศรีีธรรมราช',
#  'ร้องกวาง',
#  'นนทบุรี',
#  'สอง',
#  'ร้อยเอ็ด',
#  'สมุุทรปราการ',
#  'ปทุมทานี',
#  'ปทุมธานี',
#  'สตูล',
#  'ตราด',
#  'หนองบัวลำภู',
#  'บ้านหลวง',
#  'ศรีสะเกษ',
#  'เรือ',
#  'มาเลเซีย',
#  'พระนครศรีอยุธยา',
#  'สูงเม่น',
#  'สมุุทรสาคร',
#  'กาฬสิินธุ์',
#  'นาวัง',
#  'เพรชบุรี',
#  'บึงโขงหลง',
#  'กัมพูชา',
#  'ยโสธร',
#  'ชลบุรี',
#  'หนองม่วงไข่',
#  'ภูเพียง',
#  'อุบลราขธานี',
#  'ยานนาวา',
#  'อุดรธานีี',
#  'เมืองน่าน',
#  'อุุดรธานี',
#  'ร้้อยเอ็ด',
#  'สุมทรสาคร',
#  'เพชบุรี',
#  'สองแคว',
#  'นครสววรค์',
#  'เลย',
#  'ชลบุุรี',
#  'นราธิวาส',
#  'อุบลราชธานี',
#  'สุุราษฎร์ธานี',
#  'สมุทราสาคร',
#  'กำแพงเพชร',
#  'ราชบุรี',
#  'มุกดาหาร',
#  'พระนครศรียุธยา',
#  'ลพบุรี',
#  'หนองบัวลำภูู',
#  'นครศรี',
#  'มหาสารคาม',
#  'สมุทราปราการ',
#  'ลำปาง',
#  'อยุธยา',
#  'นครศรีราชสีมา',
#  'นครนายก',
#  'เพรบุรี',
#  'ประจวบครีขันธ์',
#  'หนองคาย',
#  'สุพรรณบุรี',
#  'ชัยภูมิ',
#  'กาฬสินธิ์',
#  'ลอง',
#  'เชียงใหม่',
#  'บุรีรัมย์',
#  'ลำพูน',
#  'ูภูเก็ต',
#  'ร้อยเอ้ด',
#  'พระนครศรีอยุทธยา',
#  'พระนตรศรีอยุธยา',
#  'เวียงสา',
#  'ระยอง',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'อำนาจเจริญ',
#  'มหาสารคราม',
#  'กรุงเทพมหานคร',
#  'เด่นชัย',
#  'สมุทรปาการ',
#  'หนองบััวลำภู',
#  'ลพบรี',
#  'ปลายพระยา',
#  'พระนครศีรอยุธยา',
#  'พระนครศีอยุธยา',
#  'สมุุทสาคร',
#  'พระนครศรีอยุธนา',
#  'นนทุบรี',
#  'ปัว',
#  'วังชิ้น',
#  'สุทรปราการ',
#  'ร้อยเอ็็ด',
#  'ตรัง',
#  'สุรินทร์',
#  'อุดรธานี',
#  'สรแก้ว',
#  'สกลนคร',
#  'ยะลา',
#  'ชุมพร',
#  'สมุทสงคราม',
#  'ขอนแก่น',
#  'ขอนแก่่น',
#  'ปทุมธานีี',
#  'อุุดรธาน',
#  'พม่า',
#  'สมุทรปราการ',
#  'ไม่ระบุ',
#  'ปราจีนบุรี',
#  'บางกะปิ',
#  'ปัตตานี',
#  'น่าน',
#  'นตรปฐม',
#  'กาฬสินธ์ุ',
#  'สมุทสาคร',
#  'ระนอง',
#  'สงขลา\u200b',
#  'ภูเก็ต',
#  'นครศรธรรมาช',
#  'นครพนม',
#  'พิจิตร',
#  'สงขลา',
#  'พิษณุโลก',
#  'เวียงจันทร์',
#  'ศีรษะเกษ',
#  'นครสวรรค์',
#  'พัทลุง',
#  'นครปฐม',
#  'เมือง',
#  'ศรีษะเกษ',
#  'นาราธิวาส',
#  'อุทัยธานี',
#  'นครศรีธรรรมราช',
#  'เพชรบูรณ์',
#  'จ.ปัตตานี',
#  'ชุุมพร',
#  'สมทรสาคร',
#  'เพชรบุรี',
#  'นครประฐม',
#  'สุมุทรสาคร',
#  'อุุตรดิตถ์',
#  'ชัยนาท',
#  'สุมุทรปราการ']

# %%
dataCN = data_cases[data_cases['province_of_onset']==X[0]]

# %%
dataCN
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, Unit, nationality, province_of_isolation, risk, province_of_onset, district_of_onset, new col]
# Index: []

# %%
prov_list = list()
for e_province in list(set(data_cases['province_of_onset']))[1:]:
    print(e_province)
    dataCN = data_cases[data_cases['province_of_onset']==e_province]
    dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
    prov_list.append(dataCN) ## 
dataALL = pd.concat(prov_list)
# Out:
# นครศรีธรรมราช
# นครราชสีมา
# อ่างทอง
# นคนปฐม
# สมุุทรสงคราม
# กาฬสินธุ์
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สุโขทัย
# สิงห์บุรี
# สมุทปราการ
# บึึงกาฬ
# สระบุรี
# อุตรดิตถ์
# ธารโต
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ปัตตานี​
# พังงา
# สระแก้ว
# บึงกาฬ
# ประจวบคีรีขันธ์
# ปทุุมธานี
# สระบุุรี
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# กาญจนบุรี
# แพร่
# สถานที่ทำงาน
# ชััยภูมิ
# สมุทรสาคร
# ประจวบคีรีขันธื
# จังหวัดร้อยเอ็ด
# ศีรสะเกษ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# พะเยา
# สงขขลา
# สมุทรสงคราม
# กระบี่
# ศรีีสะเกษ
# หนองบัวลำำภู
# อุุทัยธานี
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# แม่ฮ่องสอน
# ลพบุุรี
# นครนาชสีมา
# ตาก
# เชียงราย
# สุราษฎร์ธานี
# นครราชธสีมา
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# นคปฐม
# นครศรีีธรรมราช
# ร้องกวาง
# นนทบุรี
# สอง
# ร้อยเอ็ด
# สมุุทรปราการ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ปทุมทานี
# ปทุมธานี
# สตูล
# ตราด
# หนองบัวลำภู
# บ้านหลวง
# ศรีสะเกษ
# เรือ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# มาเลเซีย
# พระนครศรีอยุธยา
# สูงเม่น
# สมุุทรสาคร
# กาฬสิินธุ์
# นาวัง
# เพรชบุรี
# บึงโขงหลง
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# กัมพูชา
# ยโสธร
# ชลบุรี
# หนองม่วงไข่
# ภูเพียง
# อุบลราขธานี
# ยานนาวา
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# อุดรธานีี
# เมืองน่าน
# อุุดรธานี
# ร้้อยเอ็ด
# สุมทรสาคร
# เพชบุรี
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สองแคว
# นครสววรค์
# เลย
# ชลบุุรี
# นราธิวาส
# อุบลราชธานี
# สุุราษฎร์ธานี
# สมุทราสาคร
# กำแพงเพชร
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ราชบุรี
# มุกดาหาร
# พระนครศรียุธยา
# ลพบุรี
# หนองบัวลำภูู
# นครศรี
# มหาสารคาม
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สมุทราปราการ
# ลำปาง
# อยุธยา
# นครศรีราชสีมา
# นครนายก
# เพรบุรี
# ประจวบครีขันธ์
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# หนองคาย
# สุพรรณบุรี
# ชัยภูมิ
# กาฬสินธิ์
# ลอง
# เชียงใหม่
# บุรีรัมย์
# ลำพูน
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ูภูเก็ต
# ร้อยเอ้ด
# พระนครศรีอยุทธยา
# พระนตรศรีอยุธยา
# เวียงสา
# ระยอง
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# จันทบุรี
# ฉะเชิงเทรา
# อำนาจเจริญ
# มหาสารคราม
# กรุงเทพมหานคร
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# ...
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สมุทสงคราม
# ขอนแก่น
# ขอนแก่่น
# ปทุมธานีี
# อุุดรธาน
# พม่า
# สมุทรปราการ
# ไม่ระบุ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# ปราจีนบุรี
# บางกะปิ
# ปัตตานี
# น่าน
# นตรปฐม
# กาฬสินธ์ุ
# สมุทสาคร
# ระนอง
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สงขลา​
# ภูเก็ต
# นครศรธรรมาช
# นครพนม
# พิจิตร
# สงขลา
# พิษณุโลก
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# เวียงจันทร์
# ศีรษะเกษ
# นครสวรรค์
# พัทลุง
# นครปฐม
# เมือง
# ศรีษะเกษ
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# นาราธิวาส
# อุทัยธานี
# นครศรีธรรรมราช
# เพชรบูรณ์
# จ.ปัตตานี
# ชุุมพร
# สมทรสาคร
# เพชรบุรี
# นครประฐม
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# สุมุทรสาคร
# อุุตรดิตถ์
# ชัยนาท
# สุมุทรปราการ

# %%
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 46          47      5/3/2020  ...           ท่าศาลา      46
# 496        497     22/3/2020  ...             เมือง     496
# 513        514     22/3/2020  ...             ชะอวด     513
# 617        618     23/3/2020  ...             ชะอวด     617
# 618        619     23/3/2020  ...             ชะอวด     618
# ...        ...           ...  ...               ...     ...
# 498164  498165     26/7/2021  ...            สรรพยา  498164
# 498165  498166     26/7/2021  ...            สรรพยา  498165
# 498166  498167     26/7/2021  ...            สรรพยา  498166
# 498167  498168     26/7/2021  ...            สรรพยา  498167
# 349420  349421     13/7/2021  ...          บางเสาธง  349420
#
# [447605 rows x 12 columns]

# %%
datamissingonset = data_cases[pd.isna(data_cases['province_of_onset'])]
datamissingonset
# Out:
#            No. announce_date  ... district_of_onset new col
# 415        416     22/3/2020  ...               NaN     415
# 530        531     22/3/2020  ...               NaN     530
# 556        557     22/3/2020  ...               NaN     556
# 577        578     22/3/2020  ...               NaN     577
# 589        590     22/3/2020  ...               NaN     589
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [65017 rows x 12 columns]

# %%
datamissingonset[['risk']] = datamissingonset[['risk']].fillna(datamissingonset[['risk']].dropna().mode().iloc[0,0])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dataALL = pd.concat([dataALL,datamissingonset])

# %%
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 46          47      5/3/2020  ...           ท่าศาลา      46
# 496        497     22/3/2020  ...             เมือง     496
# 513        514     22/3/2020  ...             ชะอวด     513
# 617        618     23/3/2020  ...             ชะอวด     617
# 618        619     23/3/2020  ...             ชะอวด     618
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# new col                  False
# dtype: bool

# %%
dataALL = dataALL.sort_values(by='No.')
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL.keys()
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset', 'new col'],
#       dtype='object')

# %% [markdown]
# ## การทำงานกับ Datetime-Timestamp
#
# https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587
#
# https://realpython.com/python-datetime/

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1     12/1/2020  ...               NaN       0
# 1            2     17/1/2020  ...               NaN       1
# 2            3     22/1/2020  ...             เมือง       2
# 3            4     22/1/2020  ...               NaN       3
# 4            5     24/1/2020  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618     26/7/2021  ...               NaN  512617
# 512618  512619     26/7/2021  ...               NaN  512618
# 512619  512620     26/7/2021  ...               NaN  512619
# 512620  512621     26/7/2021  ...               NaN  512620
# 512621  512622     26/7/2021  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
data_cases.sort_values(by=['announce_date']).iloc[270:290]
# Out:
#        No. announce_date  ... district_of_onset new col
# 6954  6955      1/1/2021  ...               NaN    6954
# 6963  6964      1/1/2021  ...               NaN    6963
# 6961  6962      1/1/2021  ...               NaN    6961
# 6960  6961      1/1/2021  ...               NaN    6960
# 6959  6960      1/1/2021  ...               NaN    6959
# 6958  6959      1/1/2021  ...               NaN    6958
# 6957  6958      1/1/2021  ...               NaN    6957
# 6956  6957      1/1/2021  ...               NaN    6956
# 6962  6963      1/1/2021  ...               NaN    6962
# 3565  3566     1/10/2020  ...            บางรัก    3565
# 3566  3567     1/10/2020  ...          บางละมุง    3566
# 3567  3568     1/10/2020  ...             บางนา    3567
# 3568  3569     1/10/2020  ...          คลองหลวง    3568
# 3569  3570     1/10/2020  ...          คลองหลวง    3569
# 3781  3782     1/11/2020  ...           ปทุมวัน    3781
# 3782  3783     1/11/2020  ...          ปากเกร็ด    3782
# 3783  3784     1/11/2020  ...            ดินแดง    3783
# 3784  3785     1/11/2020  ...            บางรัก    3784
# 4004  4005     1/12/2020  ...               NaN    4004
# 4008  4009     1/12/2020  ...           สุรวงศ์    4008
#
# [20 rows x 12 columns]

# %%
from datetime import datetime

# %%
data_cases.iloc[0,1]
# Out:
# '12/1/2020'

# %%
t = pd.to_datetime(data_cases.iloc[0,1])
t
# Out:
# Timestamp('2020-12-01 00:00:00')

# %%
t = pd.to_datetime(data_cases.iloc[0,1],dayfirst=True)
t
# Out:
# Timestamp('2020-01-12 00:00:00')

# %%
data_cases['announce_date']=pd.to_datetime(data_cases['announce_date'])

# %%
data_cases
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1    2020-12-01  ...               NaN       0
# 1            2    2020-01-17  ...               NaN       1
# 2            3    2020-01-22  ...             เมือง       2
# 3            4    2020-01-22  ...               NaN       3
# 4            5    2020-01-24  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618    2021-07-26  ...               NaN  512617
# 512618  512619    2021-07-26  ...               NaN  512618
# 512619  512620    2021-07-26  ...               NaN  512619
# 512620  512621    2021-07-26  ...               NaN  512620
# 512621  512622    2021-07-26  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL['announce_date']=pd.to_datetime(dataALL['announce_date'],dayfirst=True)

# %%
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1    2020-01-12  ...               NaN       0
# 1            2    2020-01-17  ...               NaN       1
# 2            3    2020-01-22  ...             เมือง       2
# 3            4    2020-01-22  ...               NaN       3
# 4            5    2020-01-24  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618    2021-07-26  ...               NaN  512617
# 512618  512619    2021-07-26  ...               NaN  512618
# 512619  512620    2021-07-26  ...               NaN  512619
# 512620  512621    2021-07-26  ...               NaN  512620
# 512621  512622    2021-07-26  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL[dataALL['announce_date']==datetime(day=13,month=4,year=2020)]
# Out:
#        No. announce_date  ... district_of_onset new col
# 2552  2553    2020-04-13  ...              ถลาง    2552
# 2553  2554    2020-04-13  ...              ถลาง    2553
# 2554  2555    2020-04-13  ...             ธารโต    2554
# 2555  2556    2020-04-13  ...         ศรีสงคราม    2555
# 2556  2557    2020-04-13  ...           ยานนาวา    2556
# 2557  2558    2020-04-13  ...             วัฒนา    2557
# 2558  2559    2020-04-13  ...              ถลาง    2558
# 2559  2560    2020-04-13  ...              ถลาง    2559
# 2560  2561    2020-04-13  ...              ถลาง    2560
# 2561  2562    2020-04-13  ...              ถลาง    2561
# 2562  2563    2020-04-13  ...               NaN    2562
# 2563  2564    2020-04-13  ...            รังสิต    2563
# 2564  2565    2020-04-13  ...               NaN    2564
# 2565  2566    2020-04-13  ...               NaN    2565
# 2566  2567    2020-04-13  ...               NaN    2566
# 2567  2568    2020-04-13  ...               NaN    2567
# 2568  2569    2020-04-13  ...           มีนบุรี    2568
# 2569  2570    2020-04-13  ...               NaN    2569
# 2570  2571    2020-04-13  ...             เมือง    2570
# 2571  2572    2020-04-13  ...             เมือง    2571
# 2572  2573    2020-04-13  ...               NaN    2572
# 2573  2574    2020-04-13  ...               NaN    2573
# 2574  2575    2020-04-13  ...           บางกะปิ    2574
# 2575  2576    2020-04-13  ...          เมืองใต้    2575
# 2576  2577    2020-04-13  ...             เมือง    2576
# 2577  2578    2020-04-13  ...            ควนโดน    2577
# 2578  2579    2020-04-13  ...            ควนโดน    2578
# 2579  2580    2020-04-13  ...             สะเตง    2579
#
# [28 rows x 12 columns]

# %%
dataALL[(dataALL['announce_date']>=datetime(day=13,month=4,year=2020)) & (dataALL['announce_date']<=datetime(day=15,month=4,year=2020))]
# Out:
#        No. announce_date  ... district_of_onset new col
# 2552  2553    2020-04-13  ...              ถลาง    2552
# 2553  2554    2020-04-13  ...              ถลาง    2553
# 2554  2555    2020-04-13  ...             ธารโต    2554
# 2555  2556    2020-04-13  ...         ศรีสงคราม    2555
# 2556  2557    2020-04-13  ...           ยานนาวา    2556
# ...    ...           ...  ...               ...     ...
# 2639  2640    2020-04-15  ...           รือเสาะ    2639
# 2640  2641    2020-04-15  ...           บางกะปิ    2640
# 2641  2642    2020-04-15  ...           สวนหลวง    2641
# 2642  2643    2020-04-15  ...           คลองสาน    2642
# 2643  2644    2020-04-15  ...          ลาดพร้าว    2643
#
# [92 rows x 12 columns]

# %% [markdown]
# # Smooth data by Binning

# %%
dataALL.iloc[2000:2500,4]
# Out:
# 2000    34.0
# 2001    31.0
# 2002    58.0
# 2003    56.0
# 2004    37.0
#         ...
# 2495    21.0
# 2496     4.0
# 2497    45.0
# 2498    30.0
# 2499    40.0
# Name: age, Length: 500, dtype: float64

# %%
my_data = dataALL.iloc[2000:2500,4]

# %%
plt.scatter(range(len(my_data)),my_data)

# %% [markdown]
# ### Sort

# %%
my_data_sorted = my_data.sort_values()

# %%
my_data_sorted
# Out:
# 2455     1.0
# 2259     1.0
# 2180     2.0
# 2448     2.0
# 2376     3.0
#         ...
# 2494    75.0
# 2337    77.0
# 2219    78.0
# 2183    81.0
# 2483    91.0
# Name: age, Length: 500, dtype: float64

# %%
plt.scatter(range(len(my_data)),my_data_sorted)

# %% [markdown]
# ### Bin - Rep

# %%
import numpy as np

# %% [markdown]
# * 0  :50     i=0   50*i : (50*i)+50
# * 50 :100    i=1   50*i : (50*i)+50
# * 100:150    i=2   50*i : (50*i)+50

# %%
bin = 10
bin_r = list()
step = int(len(my_data_sorted)/bin)
for i in range(bin):
    this_data = my_data_sorted[(step*i):(step*i)+step]    #ตัดข้อมูล
    rep = np.mean(this_data)   #เลือกตัวแทน
    bin_r.append(rep)

# %%
list(range(0,len(my_data_sorted),50))
# Out:
# [0, 50, 100, 150, 200, 250, 300, 350, 400, 450]

# %%
bin = 10
bin_r = list()
step = int(len(my_data_sorted)/bin)
for start in range(0,len(my_data_sorted),50):
    this_data = my_data_sorted[start:start+step]    #ตัดข้อมูล
    rep = np.mean(this_data)  #เลือกตัวแทน
    bin_r.append(rep)

# %%
bin_r
# Out:
# [14.74,
#  24.0,
#  28.24,
#  32.28,
#  35.82235762327721,
#  39.14,
#  43.84,
#  49.74,
#  56.56,
#  67.0]

# %% [markdown]
# ### Smooth

# %%
my_data_smoothed = list()
step = 0
this_bin = 0
for i in my_data_sorted:
    if step < 50:
        my_data_smoothed.append({'old_v':i,'new_v':bin_r[this_bin]})
        step = step + 1
    else:
        step = 0
        this_bin = this_bin + 1
        my_data_smoothed.append({'old_v':i,'new_v':bin_r[this_bin]})

# %%
my_data_smoothed
# Out:
# [{'new_v': 14.74, 'old_v': 1.0},
#  {'new_v': 14.74, 'old_v': 1.0},
#  {'new_v': 14.74, 'old_v': 2.0},
#  {'new_v': 14.74, 'old_v': 2.0},
#  {'new_v': 14.74, 'old_v': 3.0},
#  {'new_v': 14.74, 'old_v': 3.0},
#  {'new_v': 14.74, 'old_v': 4.0},
#  {'new_v': 14.74, 'old_v': 5.0},
#  {'new_v': 14.74, 'old_v': 5.0},
#  {'new_v': 14.74, 'old_v': 7.0},
#  {'new_v': 14.74, 'old_v': 7.0},
#  {'new_v': 14.74, 'old_v': 8.0},
#  {'new_v': 14.74, 'old_v': 9.0},
#  {'new_v': 14.74, 'old_v': 10.0},
#  {'new_v': 14.74, 'old_v': 11.0},
#  {'new_v': 14.74, 'old_v': 11.0},
#  {'new_v': 14.74, 'old_v': 13.0},
#  {'new_v': 14.74, 'old_v': 13.0},
#  {'new_v': 14.74, 'old_v': 15.0},
#  {'new_v': 14.74, 'old_v': 15.0},
#  {'new_v': 14.74, 'old_v': 15.0},
#  {'new_v': 14.74, 'old_v': 16.0},
#  {'new_v': 14.74, 'old_v': 17.0},
#  {'new_v': 14.74, 'old_v': 17.0},
#  {'new_v': 14.74, 'old_v': 18.0},
#  {'new_v': 14.74, 'old_v': 18.0},
#  {'new_v': 14.74, 'old_v': 18.0},
#  {'new_v': 14.74, 'old_v': 19.0},
#  {'new_v': 14.74, 'old_v': 19.0},
#  {'new_v': 14.74, 'old_v': 19.0},
#  {'new_v': 14.74, 'old_v': 19.0},
#  {'new_v': 14.74, 'old_v': 19.0},
#  {'new_v': 14.74, 'old_v': 20.0},
#  {'new_v': 14.74, 'old_v': 20.0},
#  {'new_v': 14.74, 'old_v': 20.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 21.0},
#  {'new_v': 14.74, 'old_v': 22.0},
#  {'new_v': 14.74, 'old_v': 22.0},
#  {'new_v': 14.74, 'old_v': 22.0},
#  {'new_v': 24.0, 'old_v': 22.0},
#  {'new_v': 24.0, 'old_v': 22.0},
#  {'new_v': 24.0, 'old_v': 22.0},
#  {'new_v': 24.0, 'old_v': 22.0},
#  {'new_v': 24.0, 'old_v': 22.0},
#  {'new_v': 24.0, 'old_v': 22.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 23.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 24.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 25.0},
#  {'new_v': 24.0, 'old_v': 26.0},
#  {'new_v': 24.0, 'old_v': 26.0},
#  {'new_v': 24.0, 'old_v': 26.0},
#  {'new_v': 24.0, 'old_v': 26.0},
#  {'new_v': 24.0, 'old_v': 26.0},
#  {'new_v': 24.0, 'old_v': 26.0},
#  {'new_v': 24.0, 'old_v': 26.0},
#  {'new_v': 28.24, 'old_v': 26.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 27.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 28.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 29.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 28.24, 'old_v': 30.0},
#  {'new_v': 32.28, 'old_v': 30.0},
#  {'new_v': 32.28, 'old_v': 30.0},
#  {'new_v': 32.28, 'old_v': 30.0},
#  {'new_v': 32.28, 'old_v': 30.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 31.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 32.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 33.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 34.0},
#  {'new_v': 32.28, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.0},
#  {'new_v': 35.82235762327721, 'old_v': 35.52947029096511},
#  {'new_v': 35.82235762327721, 'old_v': 35.52947029096511},
#  {'new_v': 35.82235762327721, 'old_v': 35.52947029096511},
#  {'new_v': 35.82235762327721, 'old_v': 35.52947029096511},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 36.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 37.0},
#  {'new_v': 35.82235762327721, 'old_v': 38.0},
#  {'new_v': 35.82235762327721, 'old_v': 38.0},
#  {'new_v': 35.82235762327721, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 38.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 39.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 40.0},
#  {'new_v': 39.14, 'old_v': 41.0},
#  {'new_v': 39.14, 'old_v': 41.0},
#  {'new_v': 39.14, 'old_v': 41.0},
#  {'new_v': 39.14, 'old_v': 42.0},
#  {'new_v': 39.14, 'old_v': 42.0},
#  {'new_v': 39.14, 'old_v': 42.0},
#  {'new_v': 39.14, 'old_v': 42.0},
#  {'new_v': 39.14, 'old_v': 42.0},
#  {'new_v': 39.14, 'old_v': 42.0},
#  {'new_v': 39.14, 'old_v': 42.0},
#  {'new_v': 43.84, 'old_v': 42.0},
#  {'new_v': 43.84, 'old_v': 42.0},
#  {'new_v': 43.84, 'old_v': 42.0},
#  {'new_v': 43.84, 'old_v': 42.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 43.0},
#  {'new_v': 43.84, 'old_v': 44.0},
#  {'new_v': 43.84, 'old_v': 44.0},
#  {'new_v': 43.84, 'old_v': 44.0},
#  {'new_v': 43.84, 'old_v': 44.0},
#  {'new_v': 43.84, 'old_v': 44.0},
#  {'new_v': 43.84, 'old_v': 44.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 45.0},
#  {'new_v': 43.84, 'old_v': 46.0},
#  {'new_v': 43.84, 'old_v': 46.0},
#  {'new_v': 43.84, 'old_v': 46.0},
#  {'new_v': 43.84, 'old_v': 46.0},
#  {'new_v': 43.84, 'old_v': 46.0},
#  {'new_v': 43.84, 'old_v': 47.0},
#  {'new_v': 43.84, 'old_v': 47.0},
#  {'new_v': 43.84, 'old_v': 47.0},
#  {'new_v': 43.84, 'old_v': 47.0},
#  {'new_v': 43.84, 'old_v': 47.0},
#  {'new_v': 43.84, 'old_v': 47.0},
#  {'new_v': 43.84, 'old_v': 47.0},
#  {'new_v': 43.84, 'old_v': 47.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 48.0},
#  {'new_v': 49.74, 'old_v': 49.0},
#  {'new_v': 49.74, 'old_v': 49.0},
#  {'new_v': 49.74, 'old_v': 49.0},
#  {'new_v': 49.74, 'old_v': 49.0},
#  {'new_v': 49.74, 'old_v': 49.0},
#  {'new_v': 49.74, 'old_v': 49.0},
#  {'new_v': 49.74, 'old_v': 49.0},
#  {'new_v': 49.74, 'old_v': 49.0},
#  {'new_v': 49.74, 'old_v': 50.0},
#  {'new_v': 49.74, 'old_v': 50.0},
#  {'new_v': 49.74, 'old_v': 50.0},
#  {'new_v': 49.74, 'old_v': 50.0},
#  {'new_v': 49.74, 'old_v': 50.0},
#  {'new_v': 49.74, 'old_v': 50.0},
#  {'new_v': 49.74, 'old_v': 50.0},
#  {'new_v': 49.74, 'old_v': 50.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 51.0},
#  {'new_v': 49.74, 'old_v': 52.0},
#  {'new_v': 49.74, 'old_v': 52.0},
#  {'new_v': 49.74, 'old_v': 52.0},
#  {'new_v': 49.74, 'old_v': 52.0},
#  {'new_v': 49.74, 'old_v': 53.0},
#  {'new_v': 49.74, 'old_v': 53.0},
#  {'new_v': 49.74, 'old_v': 53.0},
#  {'new_v': 49.74, 'old_v': 53.0},
#  {'new_v': 49.74, 'old_v': 54.0},
#  {'new_v': 49.74, 'old_v': 54.0},
#  {'new_v': 49.74, 'old_v': 54.0},
#  {'new_v': 49.74, 'old_v': 54.0},
#  {'new_v': 49.74, 'old_v': 54.0},
#  {'new_v': 49.74, 'old_v': 54.0},
#  {'new_v': 49.74, 'old_v': 54.0},
#  {'new_v': 49.74, 'old_v': 54.0},
#  {'new_v': 56.56, 'old_v': 54.0},
#  {'new_v': 56.56, 'old_v': 54.0},
#  {'new_v': 56.56, 'old_v': 55.0},
#  {'new_v': 56.56, 'old_v': 55.0},
#  {'new_v': 56.56, 'old_v': 55.0},
#  {'new_v': 56.56, 'old_v': 55.0},
#  {'new_v': 56.56, 'old_v': 55.0},
#  {'new_v': 56.56, 'old_v': 55.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 56.0},
#  {'new_v': 56.56, 'old_v': 57.0},
#  {'new_v': 56.56, 'old_v': 57.0},
#  {'new_v': 56.56, 'old_v': 57.0},
#  {'new_v': 56.56, 'old_v': 57.0},
#  {'new_v': 56.56, 'old_v': 57.0},
#  {'new_v': 56.56, 'old_v': 57.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 58.0},
#  {'new_v': 56.56, 'old_v': 59.0},
#  {'new_v': 56.56, 'old_v': 59.0},
#  {'new_v': 56.56, 'old_v': 59.0},
#  {'new_v': 56.56, 'old_v': 59.0},
#  {'new_v': 56.56, 'old_v': 59.0},
#  {'new_v': 56.56, 'old_v': 59.0},
#  {'new_v': 56.56, 'old_v': 59.0},
#  {'new_v': 56.56, 'old_v': 59.0},
#  {'new_v': 56.56, 'old_v': 60.0},
#  {'new_v': 56.56, 'old_v': 60.0},
#  {'new_v': 56.56, 'old_v': 60.0},
#  {'new_v': 56.56, 'old_v': 60.0},
#  {'new_v': 56.56, 'old_v': 60.0},
#  {'new_v': 56.56, 'old_v': 60.0},
#  {'new_v': 56.56, 'old_v': 60.0},
#  {'new_v': 56.56, 'old_v': 60.0},
#  {'new_v': 67.0, 'old_v': 60.0},
#  {'new_v': 67.0, 'old_v': 61.0},
#  {'new_v': 67.0, 'old_v': 62.0},
#  {'new_v': 67.0, 'old_v': 62.0},
#  {'new_v': 67.0, 'old_v': 62.0},
#  {'new_v': 67.0, 'old_v': 62.0},
#  {'new_v': 67.0, 'old_v': 63.0},
#  {'new_v': 67.0, 'old_v': 63.0},
#  {'new_v': 67.0, 'old_v': 63.0},
#  {'new_v': 67.0, 'old_v': 63.0},
#  {'new_v': 67.0, 'old_v': 64.0},
#  {'new_v': 67.0, 'old_v': 64.0},
#  {'new_v': 67.0, 'old_v': 64.0},
#  {'new_v': 67.0, 'old_v': 64.0},
#  {'new_v': 67.0, 'old_v': 64.0},
#  {'new_v': 67.0, 'old_v': 64.0},
#  {'new_v': 67.0, 'old_v': 65.0},
#  {'new_v': 67.0, 'old_v': 65.0},
#  {'new_v': 67.0, 'old_v': 65.0},
#  {'new_v': 67.0, 'old_v': 65.0},
#  {'new_v': 67.0, 'old_v': 66.0},
#  {'new_v': 67.0, 'old_v': 67.0},
#  {'new_v': 67.0, 'old_v': 67.0},
#  {'new_v': 67.0, 'old_v': 68.0},
#  {'new_v': 67.0, 'old_v': 68.0},
#  {'new_v': 67.0, 'old_v': 69.0},
#  {'new_v': 67.0, 'old_v': 70.0},
#  {'new_v': 67.0, 'old_v': 71.0},
#  {'new_v': 67.0, 'old_v': 71.0},
#  {'new_v': 67.0, 'old_v': 72.0},
#  {'new_v': 67.0, 'old_v': 72.0},
#  {'new_v': 67.0, 'old_v': 73.0},
#  {'new_v': 67.0, 'old_v': 73.0},
#  {'new_v': 67.0, 'old_v': 74.0},
#  {'new_v': 67.0, 'old_v': 74.0},
#  {'new_v': 67.0, 'old_v': 74.0},
#  {'new_v': 67.0, 'old_v': 74.0},
#  {'new_v': 67.0, 'old_v': 75.0},
#  {'new_v': 67.0, 'old_v': 77.0},
#  {'new_v': 67.0, 'old_v': 78.0},
#  {'new_v': 67.0, 'old_v': 81.0},
#  {'new_v': 67.0, 'old_v': 91.0}]

# %%
my_df = pd.DataFrame(my_data_smoothed) #แปลง Dict เป็น ตาราง pandas (ยังไม่ได้สอน)
my_df
# Out:
#      old_v  new_v
# 0      1.0  14.74
# 1      1.0  14.74
# 2      2.0  14.74
# 3      2.0  14.74
# 4      3.0  14.74
# ..     ...    ...
# 495   75.0  67.00
# 496   77.0  67.00
# 497   78.0  67.00
# 498   81.0  67.00
# 499   91.0  67.00
#
# [500 rows x 2 columns]

# %%
plt.scatter(range(len(my_data)),my_df['new_v'])

# %% [markdown]
# ## แทนค่ากลับลงไปในตาราง

# %% [markdown]
# # การต่อตาราง (แนวแกน X)

# %% [markdown]
# หาจำนวนร้านค้าที่แสดงเป็นอันดับ 1-4 ที่ถูกกดเข้าไปดูหลังจาก search โดยร้านค้านั้นตั้งอยู่ที่เชียงใหม่

# %%
w_res = pd.read_csv(os.path.join(path,'w_restaurant.csv'))
w_res.head()
# Out:
#    id              name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 0   2  นครินทร์ทันตกรรม          2  ...               NaN          NaN      NaN
# 1   4      Corner House          1  ...               NaN          NaN      NaN
# 2   5    วัดโลกยสุธาราม          4  ...               NaN          NaN      NaN
# 3   6    นันท์คาราโอเกะ          1  ...               NaN          NaN      NaN
# 4   7       Buono Caffe          1  ...               NaN          NaN      NaN
#
# [5 rows x 32 columns]

# %%
search_click = pd.read_csv(os.path.join(path,'search_click.csv'))
search_click.head()
# Out:
#   click_timestamp                             search_id  ...  time_diff_nanos   ads
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1  ...     2.222400e+15  True
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e  ...     4.608380e+14  True
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224  ...     2.581490e+15  True
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b  ...     1.404580e+15  True
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639  ...     9.333590e+14  True
#
# [5 rows x 6 columns]

# %%
import numpy as np

# %%
np.random.choice(['นิชา','oil','กี้'])
# Out:
# 'oil'

# %% [markdown]
# หาร้านที่ตั้งอยู่ที่ จ.เชียงใหม่

# %%
w_res[w_res['city_name']=='Chiang Mai']
# Out:
#             id                          name  ...  pet_friendly  delivery
# 36          70                   Wrap Master  ...           0.0       1.0
# 40          75                         Sozen  ...           NaN       NaN
# 52          98           ไวท์ดราก้อน หมูกะทะ  ...           NaN       NaN
# 60         111  เต-ชา ก๋วยเตี๋ยวไข่ไดโนเสาร์  ...           0.0       0.0
# 79         147            ก๋วยเตี๋ยวเรือสะใจ  ...           NaN       NaN
# ...        ...                           ...  ...           ...       ...
# 246783  339922                 ส้มตำลำฮิมกอง  ...           NaN       NaN
# 246803  339957       ไก่ทอดปักษ์ใต้ นายหัวโต  ...           NaN       NaN
# 246808  339976             แคลิฟอร์เนียเวร็ป  ...           NaN       NaN
# 246813  339998        TOONGs COFFEE Roasters  ...           NaN       NaN
# 246826  340031                     ลาบเขยยอง  ...           NaN       NaN
#
# [15670 rows x 32 columns]

# %% [markdown]
# หา records ที่ถูก click เวลา 4-6 โมงเย็น

# %% [markdown]
# ตรวจสอบชนิดข้อมูล

# %%
search_click.iloc[0,0]
# Out:
# '11:38.9'

# %% [markdown]
# แปลงให้เป็น datetime

# %%
from datetime import datetime

# %%
pd.to_datetime(search_click.iloc[0,0])
# Out:
# Timestamp('2021-09-13 11:38:54')

# %%
#ไม่มีข้อมูล timestamp

# %% [markdown]
# records ที่ถูกแสดงเป็นอันดับที่ 1-4

# %%
search_click[(search_click['display_position']>=0)&(search_click['display_position']<=3)]
# Out:
#         click_timestamp  ...    ads
# 0               11:38.9  ...   True
# 1               30:51.3  ...   True
# 2               32:09.6  ...   True
# 3               00:59.8  ...   True
# 4               23:36.8  ...   True
# ...                 ...  ...    ...
# 1047860         00:56.4  ...  False
# 1047861         57:44.9  ...  False
# 1047862         59:39.1  ...  False
# 1047863         54:14.9  ...  False
# 1047864         43:17.6  ...  False
#
# [484569 rows x 6 columns]

# %% [markdown]
# จำนวนร้าน ที่ถูกแสดงเป็นอันดับที่ 1-4

# %%
search_click_14 = search_click[(search_click['display_position']>=0)&(search_click['display_position']<=3)].drop_duplicates(subset=['business_id'])
search_click_14
# Out:
#         click_timestamp  ...    ads
# 0               11:38.9  ...   True
# 1               30:51.3  ...   True
# 2               32:09.6  ...   True
# 3               00:59.8  ...   True
# 4               23:36.8  ...   True
# ...                 ...  ...    ...
# 1047799         44:03.1  ...  False
# 1047829         58:02.2  ...  False
# 1047841         24:35.6  ...  False
# 1047848         49:27.0  ...  False
# 1047855         27:39.0  ...  False
#
# [78810 rows x 6 columns]

# %% [markdown]
# # การต่อตารางแนวแกน X มี 2 คำสั่ง
# * merge two table(.merge())
#
# * copy a column from other table (.map()) คล้าย ๆ merge แต่ดึงมาแค่บางคอลัมน์

# %% [markdown]
# Merge()

# %%
merge_table = search_click_14.merge(w_res,how='left',left_on='business_id',right_on='id')
merge_table
# Out:
#       click_timestamp  ... delivery
# 0             11:38.9  ...      1.0
# 1             30:51.3  ...      1.0
# 2             32:09.6  ...      NaN
# 3             00:59.8  ...      1.0
# 4             23:36.8  ...      1.0
# ...               ...  ...      ...
# 78805         44:03.1  ...      NaN
# 78806         58:02.2  ...      NaN
# 78807         24:35.6  ...      NaN
# 78808         49:27.0  ...      NaN
# 78809         27:39.0  ...      NaN
#
# [78810 rows x 38 columns]

# %% [markdown]
# Map()

# %%
search_click_14['shop_location'] = search_click_14['business_id'].map(w_res.set_index('id')['city_name'])
search_click_14
# Out:
#         click_timestamp  ...                shop_location
# 0               11:38.9  ...  Bangkok Metropolitan Region
# 1               30:51.3  ...  Bangkok Metropolitan Region
# 2               32:09.6  ...  Bangkok Metropolitan Region
# 3               00:59.8  ...  Bangkok Metropolitan Region
# 4               23:36.8  ...  Bangkok Metropolitan Region
# ...                 ...  ...                          ...
# 1047799         44:03.1  ...  Bangkok Metropolitan Region
# 1047829         58:02.2  ...  Bangkok Metropolitan Region
# 1047841         24:35.6  ...  Bangkok Metropolitan Region
# 1047848         49:27.0  ...  Bangkok Metropolitan Region
# 1047855         27:39.0  ...  Bangkok Metropolitan Region
#
# [78810 rows x 7 columns]

# %% [markdown]
# จำนวนร้าน ที่ถูกแสดงเป็นอันดับที่ 1-4 ที่อยู่เชียงใหม่

# %%
search_click_14[search_click_14['shop_location']=='Chiang Mai']
# Out:
#         click_timestamp  ... shop_location
# 64              07:53.8  ...    Chiang Mai
# 70              25:35.6  ...    Chiang Mai
# 82              00:41.4  ...    Chiang Mai
# 90              25:58.9  ...    Chiang Mai
# 91              14:57.5  ...    Chiang Mai
# ...                 ...  ...           ...
# 1047097         11:08.7  ...    Chiang Mai
# 1047717         02:31.3  ...    Chiang Mai
# 1047723         03:43.2  ...    Chiang Mai
# 1047727         42:39.8  ...    Chiang Mai
# 1047730         00:08.7  ...    Chiang Mai
#
# [5159 rows x 7 columns]

# %%
search_click_14[search_click_14['shop_location']=='Chiang Mai'].shape[0]
# Out:
# 5159

# %% [markdown]
# ## ต่อ Smooth by Binning

# %%
dataALL_cut = dataALL.iloc[2000:2500,:5]
dataALL_cut
# Out:
#        No. announce_date Notified date   sex   age
# 2000  2001    2020-04-04      3/4/2020   ชาย  34.0
# 2001  2002    2020-04-04      3/4/2020  หญิง  31.0
# 2002  2003    2020-04-04      3/4/2020  หญิง  58.0
# 2003  2004    2020-04-04      3/4/2020  หญิง  56.0
# 2004  2005    2020-04-04      3/4/2020  หญิง  37.0
# ...    ...           ...           ...   ...   ...
# 2495  2496    2020-04-11     10/4/2020   ชาย  21.0
# 2496  2497    2020-04-11     10/4/2020  หญิง   4.0
# 2497  2498    2020-04-11     10/4/2020   ชาย  45.0
# 2498  2499    2020-04-11     10/4/2020  หญิง  30.0
# 2499  2500    2020-04-11     10/4/2020   ชาย  40.0
#
# [500 rows x 5 columns]

# %%
my_df
# Out:
#      old_v  new_v
# 0      1.0  14.74
# 1      1.0  14.74
# 2      2.0  14.74
# 3      2.0  14.74
# 4      3.0  14.74
# ..     ...    ...
# 495   75.0  67.00
# 496   77.0  67.00
# 497   78.0  67.00
# 498   81.0  67.00
# 499   91.0  67.00
#
# [500 rows x 2 columns]

# %%
my_df_unique = my_df.drop_duplicates(subset=['old_v'])
my_df_unique
# Out:
#      old_v  new_v
# 0      1.0  14.74
# 2      2.0  14.74
# 4      3.0  14.74
# 6      4.0  14.74
# 7      5.0  14.74
# ..     ...    ...
# 495   75.0  67.00
# 496   77.0  67.00
# 497   78.0  67.00
# 498   81.0  67.00
# 499   91.0  67.00
#
# [77 rows x 2 columns]

# %%
dataALL_cut['smooth_age'] = dataALL_cut['age'].map(my_df_unique.set_index('old_v')['new_v'])
dataALL_cut
# Out:
#        No. announce_date Notified date   sex   age  smooth_age
# 2000  2001    2020-04-04      3/4/2020   ชาย  34.0   32.280000
# 2001  2002    2020-04-04      3/4/2020  หญิง  31.0   32.280000
# 2002  2003    2020-04-04      3/4/2020  หญิง  58.0   56.560000
# 2003  2004    2020-04-04      3/4/2020  หญิง  56.0   56.560000
# 2004  2005    2020-04-04      3/4/2020  หญิง  37.0   35.822358
# ...    ...           ...           ...   ...   ...         ...
# 2495  2496    2020-04-11     10/4/2020   ชาย  21.0   14.740000
# 2496  2497    2020-04-11     10/4/2020  หญิง   4.0   14.740000
# 2497  2498    2020-04-11     10/4/2020   ชาย  45.0   43.840000
# 2498  2499    2020-04-11     10/4/2020  หญิง  30.0   28.240000
# 2499  2500    2020-04-11     10/4/2020   ชาย  40.0   39.140000
#
# [500 rows x 6 columns]

# %%
plt.scatter(range(len(my_data)),my_data)

# %%
plt.scatter(range(len(my_data)),dataALL_cut['smooth_age'])

# %% [markdown]
# ## [PD] Group by

# %%
search_click.groupby('ads').count()
# Out:
#        click_timestamp  search_id  ...  display_position  time_diff_nanos
# ads                                ...
# False          1019994    1019973  ...           1019994          1019994
# True             28581      28581  ...             28581            28581
#
# [2 rows x 5 columns]

# %%
search_click[search_click['ads']==True].shape[0]
# Out:
# 28581

# %%
search_click[search_click['ads']==False].shape[0]
# Out:
# 1019994

# %% [markdown]
# ## ร้านไหนมีคน click เข้าไปดูมากที่สุด โดยพิจารณาจาก การ search 100 ครั้งล่าสุด

# %% [markdown]
# 1. หาการ search 100 ครั้งล่าสุด

# %%
search100 = search_click.sort_index(ascending=False).iloc[:100,:]
search100
# Out:
#         click_timestamp  ...    ads
# 1048574         13:51.4  ...  False
# 1048573         10:33.7  ...  False
# 1048572         11:49.4  ...  False
# 1048571         15:28.8  ...  False
# 1048570         05:28.8  ...  False
# ...                 ...  ...    ...
# 1048479         19:25.9  ...  False
# 1048478         49:08.8  ...  False
# 1048477         45:58.0  ...  False
# 1048476         18:50.9  ...  False
# 1048475         19:00.5  ...  False
#
# [100 rows x 6 columns]

# %%
search100.groupby('business_id').count()
# Out:
#              click_timestamp  search_id  display_position  time_diff_nanos  ads
# business_id
# 9640.0                     1          1                 1                1    1
# 11387.0                    1          1                 1                1    1
# 12133.0                    1          1                 1                1    1
# 44441.0                    3          3                 3                3    3
# 61441.0                    4          4                 4                4    4
# ...                      ...        ...               ...              ...  ...
# 321885.0                   1          1                 1                1    1
# 323374.0                   1          1                 1                1    1
# 331866.0                   1          1                 1                1    1
# 333433.0                   1          1                 1                1    1
# 338544.0                   1          1                 1                1    1
#
# [70 rows x 5 columns]

# %%
search100.groupby('business_id').count().sort_values(by=['click_timestamp'],ascending=False)
# Out:
#              click_timestamp  search_id  display_position  time_diff_nanos  ads
# business_id
# 130270.0                   5          5                 5                5    5
# 61441.0                    4          4                 4                4    4
# 98956.0                    4          4                 4                4    4
# 109141.0                   3          3                 3                3    3
# 207208.0                   3          3                 3                3    3
# ...                      ...        ...               ...              ...  ...
# 196321.0                   1          1                 1                1    1
# 11387.0                    1          1                 1                1    1
# 204481.0                   1          1                 1                1    1
# 206253.0                   1          1                 1                1    1
# 338544.0                   1          1                 1                1    1
#
# [70 rows x 5 columns]

# %%
search100.groupby('business_id').count().sort_values(by=['click_timestamp'],ascending=False).reset_index()
# Out:
#     business_id  click_timestamp  ...  time_diff_nanos  ads
# 0      130270.0                5  ...                5    5
# 1       61441.0                4  ...                4    4
# 2       98956.0                4  ...                4    4
# 3      109141.0                3  ...                3    3
# 4      207208.0                3  ...                3    3
# ..          ...              ...  ...              ...  ...
# 65     196321.0                1  ...                1    1
# 66      11387.0                1  ...                1    1
# 67     204481.0                1  ...                1    1
# 68     206253.0                1  ...                1    1
# 69     338544.0                1  ...                1    1
#
# [70 rows x 6 columns]

# %%
topsearch = search100.groupby('business_id').count().sort_values(by=['click_timestamp'],ascending=False).reset_index().iloc[0,0]
topsearch
# Out:
# 130270.0

# %%
w_res[w_res['id']==topsearch]['name']
# Out:
# 83878    Audrey Café
# Name: name, dtype: object

# %% [markdown]
# ### แต่ละจังหวัดมีอายุเฉลี่ยของคนที่ตรวจพบโรคเป็นกี่ปี (เรียงจากน้อยไปหามาก)

# %%
dataALL
# Out:
#            No. announce_date  ... district_of_onset new col
# 0            1    2020-01-12  ...               NaN       0
# 1            2    2020-01-17  ...               NaN       1
# 2            3    2020-01-22  ...             เมือง       2
# 3            4    2020-01-22  ...               NaN       3
# 4            5    2020-01-24  ...               NaN       4
# ...        ...           ...  ...               ...     ...
# 512617  512618    2021-07-26  ...               NaN  512617
# 512618  512619    2021-07-26  ...               NaN  512618
# 512619  512620    2021-07-26  ...               NaN  512619
# 512620  512621    2021-07-26  ...               NaN  512620
# 512621  512622    2021-07-26  ...               NaN  512621
#
# [512622 rows x 12 columns]

# %%
dataALL.groupby('province_of_onset').mean()
# Out:
#                              No.        age        new col
# province_of_onset
# กระบี่             209767.779487  31.191337  209766.779487
# กรุงเทพมหานคร      256420.533612  36.874415  256419.533612
# กัมพูชา            294560.833333  31.500000  294559.833333
# กาญจนบุรี          333000.799141  37.053101  332999.799141
# กาฬสินธิ์          406290.333333  31.333333  406289.333333
# ...                          ...        ...            ...
# เวียงจันทร์         41531.000000  26.000000   41530.000000
# เวียงสา            392002.600000  35.529470  392001.600000
# แพร่               321364.602709  35.893641  321363.602709
# แม่ฮ่องสอน         181527.775281  27.062129  181526.775281
# ไม่ระบุ            290933.875000  33.750000  290932.875000
#
# [184 rows x 3 columns]

# %%
dataprovage = dataALL.groupby('province_of_onset').mean().reset_index()[['province_of_onset','age']]
dataprovage.sort_values(by=['age'])
# Out:
#     province_of_onset        age
# 40     นครศรีีธรรมราช   2.000000
# 64          ปลายพระยา  15.000000
# 11          จ.ปัตตานี  16.000000
# 48              นาวัง  19.000000
# 116          สมทรสาคร  19.000000
# ..                ...        ...
# 127      สมุุทรสงคราม  53.505894
# 74     พระนครศีอยุธยา  54.500000
# 88            ยานนาวา  57.000000
# 108          ศีรษะเกษ  66.000000
# 26             นคนปฐม  67.000000
#
# [184 rows x 2 columns]

# %%
TH_province = pd.read_csv(os.path.join(path,'TH_province.csv'))
TH_province = TH_province.iloc[:,:2]
TH_province
# Out:
#     อันดับ      จังหวัด
# 0        1   นครราชสีมา
# 1        2    เชียงใหม่
# 2        3    กาญจนบุรี
# 3        4          ตาก
# 4        5  อุบลราชธานี
# ..     ...          ...
# 72      73    สมุทรสาคร
# 73      74    สิงห์บุรี
# 74      75      นนทบุรี
# 75      76       ภูเก็ต
# 76      77  สมุทรสงคราม
#
# [77 rows x 2 columns]

# %%
TH_province['avg_age'] = TH_province['จังหวัด'].map(dataprovage.set_index('province_of_onset')['age'])
TH_province.sort_values(by=['avg_age'])
# Out:
#     อันดับ      จังหวัด    avg_age
# 7        8   แม่ฮ่องสอน  27.062129
# 63      64         สตูล  29.910839
# 26      27      สระแก้ว  31.037537
# 44      45       กระบี่  31.191337
# 52      53        พังงา  31.598954
# ..     ...          ...        ...
# 38      39   สุพรรณบุรี  37.149560
# 74      75      นนทบุรี  37.202312
# 53      54        ยโสธร  38.306257
# 73      74    สิงห์บุรี  38.431886
# 76      77  สมุทรสงคราม  38.663481
#
# [77 rows x 3 columns]

# %% [markdown]
# ## [PD] Sample record

# %%
dataALL.shape
# Out:
# (512622, 12)

# %% [markdown]
# ####sampling

# %%
dataALL.sample(n=100)
# Out:
#            No. announce_date  ... district_of_onset new col
# 54698    54699    2021-04-25  ...               NaN   54698
# 157831  157832    2021-05-31  ...               NaN  157831
# 444007  444008    2021-07-22  ...            สอยดาว  444007
# 293263  293264    2021-07-06  ...           จตุจักร  293263
# 206326  206327    2021-06-17  ...           ลำลูกกา  206326
# ...        ...           ...  ...               ...     ...
# 478796  478797    2021-07-24  ...           คลองสาน  478796
# 219877  219878    2021-06-21  ...            บางพลี  219877
# 272045  272046    2021-07-03  ...    เมืองสมุทรสาคร  272045
# 164694  164695    2021-06-02  ...               NaN  164694
# 216224  216225    2021-06-20  ...            กันตัง  216224
#
# [100 rows x 12 columns]

# %% [markdown]
# #### bootstrap sampling (สุ่มแบบใส่คืน)

# %%
dataALL.sample(n=100,replace=True)
# Out:
#            No. announce_date  ... district_of_onset new col
# 491850  491851    2021-07-25  ...               NaN  491850
# 372368  372369    2021-07-16  ...            แม่สอด  372368
# 28391    28392    2021-03-25  ...             บางแค   28391
# 328261  328262    2021-07-11  ...          คลองหลวง  328261
# 332346  332347    2021-07-11  ...               NaN  332346
# ...        ...           ...  ...               ...     ...
# 328352  328353    2021-07-11  ...          คลองหลวง  328352
# 368782  368783    2021-07-15  ...               NaN  368782
# 487019  487020    2021-07-25  ...            บ้านคา  487019
# 193868  193869    2021-06-13  ...           ท่าใหม่  193868
# 77800    77801    2021-05-07  ...             เมือง   77800
#
# [100 rows x 12 columns]

# %% [markdown]
# ## [PD] Save file

# %%
TH_province.sort_values(by=['avg_age']).to_csv('avg_age_prov.csv')

# %% [markdown]
# ## [PD] การสร้างตาราง pandas
#
# ![Unknown.jpg](data:image/jpeg;base64,...)

# %%
sales = [{'account':'Jones LLC', 'Jan':150, 'Feb':200, 'Mar':140},
         {'account':'Alpha Co', 'Jan':200, 'Feb':210, 'Mar':215},
         {'account':'Blue Inc', 'Jan':50, 'Feb':90, 'Mar':95}]
df = pd.DataFrame(sales)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
sales = [['Jones LLC',150,200,140],
         ['Alpha Co',200,210,215],
         ['Blue Inc',50,90,95]]
labels = ['account','Jan','Feb','Mar']
df = pd.DataFrame.from_records(sales,columns=labels)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ## Pre-test

# %% [markdown]
# ### เมืองไหนที่มีค่าเฉลี่ยของ 'weighted_average_rating' สูงที่สุด (จากตาราง w_res กับ search_click)

# %%
w_res.sort_values(by=['number_of_reviews'],ascending=False)
# Out:
#             id  ... delivery
# 122280  180285  ...      NaN
# 106405  159930  ...      NaN
# 75917   119120  ...      1.0
# 186134  262564  ...      NaN
# 228838  318728  ...      NaN
# ...        ...  ...      ...
# 177270  251301  ...      NaN
# 177269  251300  ...      NaN
# 62073   101956  ...      NaN
# 132521  193817  ...      NaN
# 128698  188709  ...      NaN
#
# [246847 rows x 32 columns]

# %%
plt.plot(range(len(w_res)),w_res.sort_values(by=['number_of_reviews'],ascending=False)['number_of_reviews'],'.b')

# %%
review100up = w_res[w_res['number_of_reviews']>100]
review100up
# Out:
#             id                          name  ...  pet_friendly  delivery
# 247        509            Masterpiece clinic  ...           NaN       NaN
# 335        636                  เปิ้ล ซีฟู้ด  ...           NaN       NaN
# 382        693                 Panlee Bakery  ...           NaN       NaN
# 608       1006          ภัตตาคารเชียงการีล่า  ...           NaN       NaN
# 850       1366  เฝอหม้อไฟ สุกี้สไตล์เวียดนาม  ...           NaN       NaN
# ...        ...                           ...  ...           ...       ...
# 245885  338823                    ส. หน้าวัง  ...           NaN       NaN
# 246138  339099                  สามเสนวิลล่า  ...           NaN       NaN
# 246281  339255                      เรือนต้น  ...           NaN       NaN
# 246299  339273                    Sushi Shin  ...           NaN       NaN
# 246485  339480                  The Sea moon  ...           NaN       NaN
#
# [854 rows x 32 columns]

# %%
review100up.groupby('city_name').mean().sort_values(by=['weighted_average_rating'],ascending=False)
# Out:
#                                         id  domain_id  ...  pet_friendly  delivery
# city_name                                              ...
# Udon Thani                   153699.000000   1.000000  ...           NaN       NaN
# Nong Khai                    231448.000000   1.000000  ...           NaN       NaN
# Lamphun                       41304.000000   1.000000  ...           NaN       NaN
# Nakhon Sawan                 139413.000000   1.000000  ...           NaN       NaN
# Chai Nat                     112028.000000   1.000000  ...           NaN       NaN
# Surat Thani                  306553.333333   1.000000  ...           NaN       NaN
# Maha Sarakham                246928.000000   1.000000  ...           NaN       NaN
# Phuket                       187648.428571   1.000000  ...      0.000000  0.000000
# Chiang Rai                   131414.000000   1.000000  ...      1.000000       NaN
# สงขลา                        204022.625000   1.000000  ...      0.000000       NaN
# Suphan Buri                  129530.000000   1.000000  ...           NaN       NaN
# Lampang                      198141.250000   1.000000  ...      0.000000  0.500000
# Samut Songkhram              182121.666667   1.000000  ...           NaN  0.000000
# Phatthalung                  280778.000000   1.000000  ...           NaN       NaN
# Phetchabun                   188721.333333   1.000000  ...           NaN       NaN
# Chiang Mai                   185661.440476   1.000000  ...      0.250000  0.125000
# Ubon Ratchathani             337400.000000   1.000000  ...           NaN       NaN
# Krabi                        125018.000000   1.000000  ...           NaN  0.000000
# Phra Nakhon Si Ayutthaya     198054.615385   1.076923  ...      0.500000  0.666667
# Chachoengsao                 101104.800000   1.000000  ...           NaN  0.000000
# Phitsanulok                  201456.400000   1.000000  ...           NaN  1.000000
# Chon Buri                    174509.839286   1.000000  ...      0.625000  0.200000
# Bangkok Metropolitan Region  178686.110909   1.030909  ...      0.263158  0.944056
# Phetchaburi                  155044.888889   1.000000  ...           NaN       NaN
# Trang                        150130.000000   1.000000  ...           NaN       NaN
# Chanthaburi                  244942.857143   1.000000  ...           NaN       NaN
# Ratchaburi                   190972.333333   1.000000  ...           NaN       NaN
# Thailand                     162212.000000   1.000000  ...           NaN  1.000000
# Kanchanaburi                 220342.000000   1.000000  ...      0.000000       NaN
# Khon Kaen                    169310.000000   1.000000  ...           NaN  1.000000
# Rayong                       185861.888889   1.000000  ...      0.000000  0.000000
# Nakhon Ratchasima            127260.692308   1.000000  ...      1.000000       NaN
# Saraburi                     106364.000000   1.000000  ...           NaN       NaN
# Nakhon Nayok                 219681.000000   1.000000  ...           NaN       NaN
# Trat                          60935.000000   1.000000  ...           NaN       NaN
# Nakhon Si Thammarat          305371.000000   1.000000  ...           NaN       NaN
# Hua Hin                      186235.235294   1.000000  ...      1.000000  0.000000
# Prachuap Khiri Khan          166121.000000   1.000000  ...           NaN       NaN
# Sing Buri                    327879.000000   1.000000  ...           NaN       NaN
# Nan                          235877.000000   1.000000  ...           NaN       NaN
#
# [40 rows x 27 columns]
